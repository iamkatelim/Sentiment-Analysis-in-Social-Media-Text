# %% [markdown]
# ## Title: Sentiment Analysis in Social Media Text using Neural Network
#
# #### Description:
# Train:
# - RNN
# - LSTM
# - biLSTM
# - Two Layer biLSTM
# - Two Layer biLSTM + 0.2 Dropout
# - Two Layer biLSTM + 0.2 Dropout + Batch Normalization

# %% [markdown]
# ### Table of Content
#
# * [Introduction](#intro)
#     * [Environment Set-up](#setup)
#     * [Define function for learning rate plot](#define_plot)
#     * [Load pre-trained word2vec model](#load_word2vec)
#     * [Load dataset](#load_dataset)
#     * [Remove possible empty comment(s)](#remove_empty)
#     <br>
# * [Word Embedding](#word_embedding)
#     * [Tokenize each comments](#tokenize)
#     * [Convert text to number](#text_number)
#     * [Word2Vec matrix](#word2vec_matrix)
#     * [Categorical target conversion](#convert_target)
#     * [Class to binary conversion](#convert_class)
#     * [Prepare one-hot encoding word matrix](#prepare_one_hot)
#     <br>
# * [Neural Network Models](#neural_network)
#     * [Recurrent Neural Network (RNN)](#rnn)
#     * [Long-Short Term Memory (LSTM)](#lstm)
#     * [Bidirectional Long-Short Term Memory (biLSTM)](#bilstm)
#     * [Two Layer Bidirectional Long-Short Term Memory (biLSTM)](#two_bilstm)
#     * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.2](#two_bilstm_02)
#     * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.5](#two_bilstm_05)
#     * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.7](#two_bilstm_07)
#     * [Dropout Comparison](#dropout_compare)
#     * [Proposed Method](#proposed)

# %% [markdown]
# ### Introduction
#
# This notebook consist of the [proposed method](#proposed).

# %% [markdown]
# #### Set-up Environment <a class="anchor" id="setup"></a>

# %%
import pandas as pd
import numpy as np
import tensorflow_addons as tfa
import gensim
from gensim.models import Word2Vec
from keras.preprocessing.text import one_hot, Tokenizer
import tqdm
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

import tensorflow as tf
import os

# %% [markdown]
# #### Define function for learning rate plot <a class="anchor" id="define_plot"></a>

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# #### Load pre-trained word2vec model <a class="anchor" id="load_word2vec"></a>

# %%
model = Word2Vec.load("../w2v/emoji_30_epochs_week5.w2v")

# %% [markdown]
# #### Load dataset <a class="anchor" id="load_dataset"></a>

# %%
test = pd.read_csv('test_emoji.csv')
df_test = pd.DataFrame(test)

train = pd.read_csv('train_emoji.csv')
df_train = pd.DataFrame(train)

val = pd.read_csv('val_emoji.csv')
df_val = pd.DataFrame(val)

all = pd.read_csv('../3 classes/with emoji.csv')
df = pd.DataFrame(all)
df.head()
# Out:
#        date                                               text sentiment  \
# 0  20210221  #dsnr salam dato.. lebih kurang 15km dari ruma...  negative
# 1  20210204  #noorhishamabdullah you’re not dr.fauci materi...  negative
# 2  20210130  #share dan #like page #the_information_news un...   neutral
# 3  20210202  1 dunia sedang & terus diperbodohkan dgn agend...  negative
# 4  20210206  1 hari sy harap angka nie turun single digit m...  positive
#
#                                            processed  \
# 0  salam dato lebih kurang  km dari rumah ke kila...
# 1  you re not dr fauci material you re just pn gr...
# 2  dan page untuk mendapatkan khabar berita yang ...
# 3  satu dunia sedang and terus diperbodohkan dgn ...
# 4  satu hari sy harap angka nie turun single digi...
#
#                                           normalized  \
# 0  salam dato lebih kurang km dari rumah ke kilan...
# 1  you re not dr fauci material you re just pun g...
# 2  dan page untuk mendapatkan khabar berita yang ...
# 3  satu dunia sedang and terus diperbodohkan deng...
# 4  satu hari sy harap angka ini turun single digi...
#
#                                                check  \
# 0  salam dato lebih kurang kkm dari rumah ke kila...
# 1  you re not dr fauci material you re just pun g...
# 2  dan page untuk mendapatkan khabar berita yang ...
# 3  satu dunia sedang and terus diperbodohkan deng...
# 4  satu hari sy harap angka ini turun single digi...
#
#                                           check_stop
# 0  kurang kkm rumah kilang pkp pkb pkpp tidak tur...
# 1                    not fauci material grabmart boy
# 2  page khabar berita saudara patani selatan thai...
# 3  dunia diperbodohkan agenda yahudi ekonomi duni...
# 4  harap angka turun single digit capai zero case...

# %% [markdown]
# #### Remove possible empty comment(s) <a class="anchor" id="remove_empty"></a>

# %%
# remove possible empty text cell
df = df[['check_stop', 'sentiment']]

print("before cleaned: ", df.shape)
df['check_stop'].replace('', np.nan, inplace=True)
df = df.dropna()
df = df.reset_index(drop=True)
print("After: ", df.shape)
# Out:
# before cleaned:  (7907, 2)
# After:  (7905, 2)

# %% [markdown]
# ### Word Embedding <a class="anchor" id="word_embedding"></a>
#
# In this section, word embedding will be prepared. There are two different types of word embedding will be prepared here:
# - Word2vec will be used as weight matrix in embedding layer in neural network layer.
# - One-hot encoding word vector as input to neural network

# %% [markdown]
# #### Tokenize each comments <a class="anchor" id="tokenize"></a>

# %%
tokenize_text = df['check_stop'].apply(lambda x: x.split())

# %% [markdown]
# #### Convert text to number  <a class="anchor" id="text_number"></a>
#
# [Tensorflow](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer#fit_on_texts):
# > Updates internal vocabulary based on a list of texts.
# In the case where texts contains lists, we assume each entry of the lists to be a token.
#
# - Each word in tokenize_text will be rearranged in dictionary item variable with arrangement from most frequently appear word to least appeared words.
# - Each word will be assigned to an integer that can represent the word, hence each word shall have unique number.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(tokenize_text)

# %% [markdown]
# #### Word2Vec matrix   <a class="anchor" id="word2vec_matrix"></a>
#
# - Convert each word in tokenize_text to corresponding value in word2vec model
#
# Variables:
# - voacb_size: contain number of unique words in dataset
# - error_count: contain number of word(s) in current dataset that missing in word2vec model
# - embedding_matrix = array with size(vocab_size + 1 * 128), each row in this matrix contain weights of the words in word2vec

# %%
vocab_size = len(tokenizer.word_index)
error_count=0
embedding_matrix = np.zeros((vocab_size + 1, 128))
for word, i in tokenizer.word_index.items():
    if word in model.wv:
        embedding_matrix[i] = model.wv[word]
    else:
        error_count += 1

# %% [markdown]
# inspect the number of word(s) missing in word2vec, in this case, we have none

# %%
error_count
# Out:
# 0

# %% [markdown]
# Have a look at first row of embedding matrix 😎

# %%
embedding_matrix[1]
# Out:
# array([-0.80821073,  0.12996967,  0.06122223,  0.07585167, -0.22558847,
#         0.18641336, -0.09077181, -1.16752696,  0.75163668, -0.12015913,
#        -0.45597985,  0.42770079,  0.23435418, -0.77817994,  0.39385429,
#         0.97037488, -0.46436679, -0.19594635, -0.31585947,  0.51815808,
#         0.79977643,  0.31490511, -1.45603395,  0.07533731,  1.5717957 ,
#         0.5696516 ,  0.98931599, -0.31019482, -0.47290641,  0.91149473,
#        -1.53172255, -0.91929543, -0.02215114,  0.3005375 , -0.45442671,
#         0.67216009, -0.84999061,  0.14322129, -1.33725905,  0.12954684,
#         0.5668509 ,  0.78362781,  0.49456924, -0.38058281,  0.43478826,
#         0.82234716, -0.53333497, -0.23124953,  0.01135817,  0.10028623,
#         0.58886218,  0.57162571,  0.06137173, -1.28368521,  0.54715991,
#         1.02292049, -0.20244384, -1.44203055,  0.91595417, -0.37601438,
#        -0.24302429, -0.03781183,  0.26310453, -1.17902577, -0.59429264,
#         0.954521  ,  0.8749783 , -1.21712708, -0.65334493,  0.32358414,
#        -0.08054629, -0.67853934,  0.26180208,  0.0165789 , -1.3626734 ,
#         0.43798056, -1.05137479, -0.03155046,  0.11909157, -1.51002026,
#         0.17525434,  0.34803328,  1.3243202 ,  0.34349141, -0.92308736,
#        -1.62190807, -0.02974017,  0.12420388,  0.35363308,  0.47289222,
#         0.26648021,  0.33726791, -0.64614636,  0.44974619,  1.25367105,
#        -0.61943376, -0.17323226, -0.96590924, -0.19759803,  1.33780038,
#         0.96633303, -1.22572494,  0.26291287,  0.25593933,  0.06104266,
#         0.36583826,  0.89492464,  1.44717741, -0.06885554, -0.04911736,
#         0.35326427,  0.40163541, -0.72555935, -0.76625162, -0.9650144 ,
#         0.61549616,  0.96231914,  0.0018517 ,  0.58970708,  0.31208056,
#         0.52387458,  0.29554927,  0.44373012, -0.40661386, -0.66800213,
#         0.92436409, -0.18565279,  0.22640467])

# %% [markdown]
# Let's also have a look at all unique words (including emoji) in the current dataset 😮

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('kes', 1), ('tidak', 2), ('pkp', 3), ('covid', 4), ('boleh', 5), ('tak', 6), ('turun', 7), ('alhamdulillah', 8), ('rakyat', 9), ('tapi', 10), ('sop', 11), ('negeri', 12), ('baru', 13), ('semoga', 14), ('kena', 15), ('jangan', 16), ('bila', 17), ('banyak', 18), ('naik', 19), ('sembuh', 20), ('malaysia', 21), ('buka', 22), ('kerajaan', 23), ('rentas', 24), ('ramai', 25), ('menurun', 26), ('balik', 27), ('kkm', 28), ('ribu', 29), ('angka', 30), ('sampai', 31), ('kerja', 32), ('duduk', 33), ('harap', 34), ('jaga', 35), ('lockdown', 36), ('tinggi', 37), ('amin', 38), ('sekolah', 39), ('bukan', 40), ('tengok', 41), ('anak', 42), ('rumah', 43), ('zero', 44), ('jadi', 45), ('raya', 46), ('keluar', 47), ('minggu', 48), ('vaksin', 49), ('tutup', 50), ('pergi', 51), ('baik', 52), ('kilang', 53), ('diri', 54), ('tiada', 55), ('negara', 56), ('ikut', 57), ('masa', 58), ('kurang', 59), ('bulan', 60), ('ekonomi', 61), ('jalan', 62), ('esok', 63), ('moga', 64), ('sektor', 65), ('habis', 66), ('meningkat', 67), ('kematian', 68), ('positif', 69), ('kluster', 70), ('nampak', 71), ('🤲', 72), ('hanya', 73), ('lama', 74), ('terima', 75), ('virus', 76), ('masjid', 77), ('😭', 78), ('kampung', 79), ('doa', 80), ('kedai', 81), ('sikit', 82), ('kasih', 83), ('cepat', 84), ('makan', 85), ('test', 86), ('salah', 87), ('mati', 88), ('kesian', 89), ('payah', 90), ('daerah', 91), ('wabak', 92), ('not', 93), ('ambil', 94), ('fikir', 95), ('no', 96), ('aktif', 97), ('berdoa', 98), ('keluarga', 99), ('tunggu', 100), ('penyakit', 101), ('pkpb', 102), ('bawa', 103), ('mco', 104), ('takut', 105), ('syukur', 106), ('solat', 107), ('masuk', 108), ('😂', 109), ('penting', 110), ('menteri', 111), ('selagi', 112), ('🤣', 113), ('mungkin', 114), ('pakai', 115), ('kali', 116), ('frontliner', 117), ('still', 118), ('🏻', 119), ('walaupun', 120), ('total', 121), ('negative', 122), ('swab', 123), ('jangkitan', 124), ('politik', 125), ('harian', 126), ('hilang', 127), ('tanpa', 128), ('susah', 129), ('duit', 130), ('mkn', 131), ('pesakit', 132), ('frontliners', 133), ('suruh', 134), ('hati', 135), ('cases', 136), ('baharu', 137), ('penurunan', 138), ('bumi', 139), ('patuh', 140), ('tahniah', 141), ('positive', 142), ('kesihatan', 143), ('hidup', 144), ('dunia', 145), ('salahkan', 146), ('ramadhan', 147), ('😅', 148), ('sehari', 149), ('belum', 150), ('sakit', 151), ('pekerja', 152), ('terbaik', 153), ('bawah', 154), ('ketat', 155), ('mask', 156), ('warga', 157), ('mohon', 158), ('hospital', 159), ('pasal', 160), ('bebas', 161), ('please', 162), ('marah', 163), ('penat', 164), ('nyawa', 165), ('malam', 166), ('mall', 167), ('manusia', 168), ('🤦', 169), ('terkawal', 170), ('alhamduli', 171), ('sabar', 172), ('menang', 173), ('👍', 174), ('mendadak', 175), ('faham', 176), ('gaji', 177), ('degil', 178), ('😢', 179), ('muka', 180), ('asing', 181), ('teruk', 182), ('stay', 183), ('swt', 184), ('pulih', 185), ('komen', 186), ('people', 187), ('darurat', 188), ('cakap', 189), ('saringan', 190), ('penuh', 191), ('cuti', 192), ('risau', 193), ('family', 194), ('saja', 195), ('elok', 196), ('puasa', 197), ('time', 198), ('bertambah', 199), ('cari', 200), ('result', 201), ('🙏', 202), ('kuarantin', 203), ('dibenarkan', 204), ('pkpp', 205), ('beli', 206), ('benda', 207), ('case', 208), ('🤔', 209), ('berkurangan', 210), ('rindu', 211), ('pru', 212), ('wave', 213), ('berkurang', 214), ('kuasa', 215), ('selamat', 216), ('pelik', 217), ('mudah', 218), ('pandai', 219), ('berkesan', 220), ('suka', 221), ('beroperasi', 222), ('dibuka', 223), ('😔', 224), ('stop', 225), ('😥', 226), ('kereta', 227), ('😊', 228), ('bagus', 229), ('like', 230), ('sebulan', 231), ('bercuti', 232), ('🙄', 233), ('inshaal', 234), ('open', 235), ('sambung', 236), ('new', 237), ('jumpa', 238), ('patuhi', 239), ('usaha', 240), ('home', 241), ('percaya', 242), ('pasar', 243), ('urusan', 244), ('government', 245), ('islam', 246), ('benarkan', 247), ('ahli', 248), ('start', 249), ('zon', 250), ('bantuan', 251), ('berjaya ...

# %% [markdown]
# #### Categorical target conversion   <a class="anchor" id="convert_target"></a>
#
# *cat.codes* is a function from library Panda that convert categorical value to numeric value. In this project, the target values that has been converted are:
# - negative -> 0
# - neutral -> 1
# - positive -> 2

# %%
df_test['sentiment'] = pd.Categorical(df_test['sentiment'])
df_test['sentiment'] = df_test.sentiment.cat.codes

df_train['sentiment'] = pd.Categorical(df_train['sentiment'])
df_train['sentiment'] = df_train.sentiment.cat.codes

df_val['sentiment'] = pd.Categorical(df_val['sentiment'])
df_val['sentiment'] = df_val.sentiment.cat.codes

# %% [markdown]
# #### Class to binary conversion   <a class="anchor" id="convert_class"></a>
#
# to_categorical():
# > Converts a class vector (integers) to binary class matrix.
#
# for example:<br>
# negative -> 0 (in previous step by *cat.codes*) -> [1 0 0]
#
# We can use the concept of [one-hot encoding] (https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/) to understand this.

# %%
y_test = df_test['sentiment']
y_train = df_train['sentiment']
y_val = df_val['sentiment']

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %% [markdown]
# #### Prepare one-hot encoding word matrix   <a class="anchor" id="prepare_one_hot"></a>
#
# - split(): tokenize the each comment into list of words
# - texts_to_sequences(): transform a sentence into list of integer according to number in tokenizer dictionary
# - pad_sequences(): pad sequence of each comments to a specific length, in this project, we accept **100 maximum words** in each comment, hence each comment will be pad to list with length 100

# %%
tokenize_train = df_train['check_stop'].apply(lambda x: x.split())
tokenize_test = df_test['check_stop'].apply(lambda x: x.split())
tokenize_val = df_val['check_stop'].apply(lambda x: x.split())


sequence = tokenizer.texts_to_sequences(x_train)
traintitle = pad_sequences(sequence, maxlen=100)
sequence = tokenizer.texts_to_sequences(x_val)
valtitle = pad_sequences(sequence, maxlen=100)
sequence = tokenizer.texts_to_sequences(x_test)
testtitle = pad_sequences(sequence, maxlen=100)

# %% [markdown]
# ### Neural Network Models   <a class="anchor" id="neural_network"></a>
#
# In this section, several neural networks will be build and train to compare with the preformance of proposed neural network.
#
# * [Recurrent Neural Network (RNN)](#rnn)
# * [Long-Short Term Memory (LSTM)](#lstm)
# * [Bidirectional Long-Short Term Memory (biLSTM)](#bilstm)
# * [Two Layer Bidirectional Long-Short Term Memory (biLSTM)](#two_bilstm)
# * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.2](#two_bilstm_02)
# * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.5](#two_bilstm_05)
# * [Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.7](#two_bilstm_07)
# * [Dropout Comparison](#dropout_compare)
# * [Proposed Method](#proposed)

# %% [markdown]
# #### Recurrent Neural Network   <a class="anchor" id="rnn"></a>
#
# Recurrent neural network (RNN) is a type of neural network where each input words are associated with certain time step [(Abdul-Mageed & Ungar, 2017)](https://aclanthology.org/P17-1067/), which able to form a short term memory to remember the previous words [(Tomas, 2010)](https://arxiv.org/abs/1310.4546). The RNN cells are linked with each other. Author [Xu (et al., 2019)](https://ieeexplore.ieee.org/document/8684825) has mentioned in paper that traditional neural network, like feedforward neural network is in effective in text analysis because it does not imposed sequence learning in text. RNN is a sequence learning model that able to learn text sequence [(Xu et al., 2019)](https://ieeexplore.ieee.org/document/8684825).

# %% [markdown]
# ##### Build neural network model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix]),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.SimpleRNN(64),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### View neural model architecture summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 128)          1571968
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 64)                12352
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,588,675
# Trainable params: 1,588,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Compile neural network with parameters

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### Define model checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 30,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_rnn_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 45)

# %% [markdown]
# ##### Train neural network model

# %%
history = model.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.state_spec
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.backward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.forward_layer.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.backward_layer.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 223/223 [==============================] - 14s 40ms/step - loss: 0.9940 - accuracy: 0.5868 - micro_f1_score: 0.5868 - macro_f1_score: 0.4032 - val_loss: 0.9291 - val_accuracy: 0.6091 - val_micro_f1_score: 0.6091 - val_macro_f1_score: 0.4522
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.45216, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.8408 - accuracy: 0.6807 - micro_f1_score: 0.6807 - macro_f1_score: 0.4862 - val_loss: 0.8721 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.4953
# Epoch 00002: val_macro_f1_score improved from 0.45216 to 0.49529, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.7537 - accuracy: 0.7345 - micro_f1_score: 0.7345 - macro_f1_score: 0.5333 - val_loss: 0.8234 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.4998
#
# Epoch 00003: val_macro_f1_score improved from 0.49529 to 0.49977, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.7001 - accuracy: 0.7458 - micro_f1_score: 0.7458 - macro_f1_score: 0.5467 - val_loss: 0.8269 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.5220
#
# Epoch 00004: val_macro_f1_score improved from 0.49977 to 0.52197, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.6353 - accuracy: 0.7700 - micro_f1_score: 0.7700 - macro_f1_score: 0.6218 - val_loss: 0.7576 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5912
#
# Epoch 00005: val_macro_f1_score improved from 0.52197 to 0.59122, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.5671 - accuracy: 0.8115 - micro_f1_score: 0.8115 - macro_f1_score: 0.7409 - val_loss: 0.7423 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6375
#
# Epoch 00006: val_macro_f1_score improved from 0.59122 to 0.63753, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 7/100
# 223/223 [==============================] - 9s 41ms/step - loss: 0.4952 - accuracy: 0.8404 - micro_f1_score: 0.8404 - macro_f1_score: 0.7779 - val_loss: 0.7516 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6370
#
# Epoch 00007: val_macro_f1_score did not improve from 0.63753
# Epoch 8/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.4581 - accuracy: 0.8568 - micro_f1_score: 0.8568 - macro_f1_score: 0.8093 - val_loss: 0.7628 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6472
#
# Epoch 00008: val_macro_f1_score improved from 0.63753 to 0.64718, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 9/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.3958 - accuracy: 0.8817 - micro_f1_score: 0.8817 - macro_f1_score: 0.8414 - val_loss: 0.8155 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6341
#
# Epoch 00009: val_macro_f1_score did not improve from 0.64718
# Epoch 10/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.4186 - accuracy: 0.8675 - micro_f1_score: 0.8675 - macro_f1_score: 0.8302 - val_loss: 0.7674 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6243
#
# Epoch 00010: val_macro_f1_score did not improve from 0.64718
# Epoch 11/100
# 223/223 [==============================] - 9s 38ms/step - loss: 0.3685 - accuracy: 0.8833 - micro_f1_score: 0.8833 - macro_f1_score: 0.8462 - val_loss: 0.7958 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6493
#
# Epoch 00011: val_macro_f1_score improved from 0.64718 to 0.64931, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 12/100
# 223/223 [==============================] - 9s 39ms/step - loss: 0.3593 - accuracy: 0.8893 - micro_f1_score: 0.8893 - macro_f1_score: 0.8571 - val_loss: 0.7940 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6759
#
# Epoch 00012: val_macro_f1_score improved from 0.64931 to 0.67593, saving model to training_1\w2v_rnn_emoji.ckpt
# Epoch 13/100
# 223/223 [==============================] - 9s 42ms/step - loss: 0.2868 - accuracy: 0.9201 - micro_f1_score: 0.9201 - macro_f1_score: 0.8959 - val_loss: 0.8303 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6340
#
# Epoch 00013: val_macro_f1_score did not improve from 0.67593
# Epoch 14/100
# 223/223 [==============================] - 9s 41ms/step - loss: 0.2734 - accuracy: 0.9228 - micro_f1_score: 0.9228 - macro_f1_score: 0.9028 - val_loss: 0.8588 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6406
#
# Epoch 00014: val_macro_f1_score did not improve from 0.67593
# Epoch 15/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.2275 - accuracy: 0.9441 - micro_f1_score: 0.9441 - macro_f1_score: 0.9279 - val_loss: 0.9348 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6485
#
# Epoch 00015: val_macro_f1_score did not improve from 0.67593
# Epoch 16/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.2148 - accuracy: 0.9453 - micro_f1_score: 0.9453 - macro_f1_score: 0.9308 - val_loss: 0.8996 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6559
#
# Epoch 00016: val_macro_f1_score did not improve from 0.67593
# Epoch 17/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1948 - accuracy: 0.9493 - micro_f1_score: 0.9493 - macro_f1_score: 0.9351 - val_loss: 0.9389 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6527
#
# Epoch 00017: val_macro_f1_score did not improve from 0.67593
# Epoch 18/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1841 - accuracy: 0.9550 - micro_f1_score: 0.9550 - macro_f1_score: 0.9443 - val_loss: 1.0409 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6309
#
# Epoch 00018: val_macro_f1_score did not improve from 0.67593
# Epoch 19/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1791 - accuracy: 0.9552 - micro_f1_score: 0.9552 - macro_f1_score: 0.9432 - val_loss: 1.0148 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6386
#
# Epoch 00019: val_macro_f1_score did not improve from 0.67593
# Epoch 20/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1687 - accuracy: 0.9601 - micro_f1_score: 0.9601 - macro_f1_score: 0.9497 - val_loss: 1.0209 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6271
#
# Epoch 00020: val_macro_f1_score did not improve from 0.67593
# Epoch 21/100
# 223/223 [==============================] - 9s 41ms/step - loss: 0.1495 - accuracy: 0.9651 - micro_f1_score: 0.9651 - macro_f1_score: 0.9547 - val_loss: 1.0911 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6240
#
# Epoch 00021: val_macro_f1_score did not improve from 0.67593
# Epoch 22/100
# 223/223 [==============================] - 9s 41ms/step - loss: 0.1625 - accuracy: 0.9575 - micro_f1_score: 0.9575 - macro_f1_score: 0.9446 - val_loss: 1.1180 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6439
#
# Epoch 00022: val_macro_f1_score did not improve from 0.67593
# Epoch 23/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1407 - accuracy: 0.9673 - micro_f1_score: 0.9673 - macro_f1_score: 0.9585 - val_loss: 1.1598 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6207
#
# Epoch 00023: val_macro_f1_score did not improve from 0.67593
# Epoch 24/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1308 - accuracy: 0.9690 - micro_f1_score: 0.9690 - macro_f1_score: 0.9594 - val_loss: 1.1088 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6328
#
# Epoch 00024: val_macro_f1_score did not improve from 0.67593
# Epoch 25/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1108 - accuracy: 0.9749 - micro_f1_score: 0.9749 - macro_f1_score: 0.9673 - val_loss: 1.1158 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6490
#
# Epoch 00025: val_macro_f1_score did not improve from 0.67593
# Epoch 26/100
# 223/223 [==============================] - 9s 41ms/step - loss: 0.1457 - accuracy: 0.9633 - micro_f1_score: 0.9633 - macro_f1_score: 0.9537 - val_loss: 1.1410 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6355
#
# Epoch 00026: val_macro_f1_score did not improve from 0.67593
# Epoch 27/100
# 223/223 [==============================] - 9s 40ms/step - loss: 0.1183 - accuracy: 0.9717 - micro_f1_score: 0.9717 - macro_f1_score: 0.9642 - val_loss: 1.2135 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6423
# Epoch 00027: val_macro_f1_score did not improve from 0.67593
# Epoch 28/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.1192 - accuracy: 0.9723 - micro_f1_score: 0.9723 - macro_f1_score: 0.9649 - val_loss: 1.2177 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.6192
#
# Epoch 00028: val_macro_f1_score did not improve from 0.67593
# Epoch 29/100
# 223/223 [==============================] - 8s 37ms/step - loss: 0.1172 - accuracy: 0.9728 - micro_f1_score: 0.9728 - macro_f1_score: 0.9658 - val_loss: 1.1980 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6236
#
# Epoch 00029: val_macro_f1_score did not improve from 0.67593
# Epoch 30/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0986 - accuracy: 0.9772 - micro_f1_score: 0.9772 - macro_f1_score: 0.9709 - val_loss: 1.1985 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6109
#
# Epoch 00030: val_macro_f1_score did not improve from 0.67593
# Epoch 31/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.1035 - accuracy: 0.9770 - micro_f1_score: 0.9770 - macro_f1_score: 0.9716 - val_loss: 1.2334 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6187
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00031: val_macro_f1_score did not improve from 0.67593
# Epoch 32/100
# 223/223 [==============================] - 8s 37ms/step - loss: 0.1036 - accuracy: 0.9760 - micro_f1_score: 0.9760 - macro_f1_score: 0.9694 - val_loss: 1.2357 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.6006
#
# Epoch 00032: val_macro_f1_score did not improve from 0.67593
# Epoch 33/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0928 - accuracy: 0.9791 - micro_f1_score: 0.9791 - macro_f1_score: 0.9748 - val_loss: 1.2409 - val_accuracy: 0.6548 - val_micro_f1_score: 0.6548 - val_macro_f1_score: 0.6060
#
# Epoch 00033: val_macro_f1_score did not improve from 0.67593
# Epoch 34/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0914 - accuracy: 0.9796 - micro_f1_score: 0.9796 - macro_f1_score: 0.9743 - val_loss: 1.2448 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6161
#
# Epoch 00034: val_macro_f1_score did not improve from 0.67593
# Epoch 35/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0916 - accuracy: 0.9789 - micro_f1_score: 0.9789 - macro_f1_score: 0.9740 - val_loss: 1.2591 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6161
#
# Epoch 00035: val_macro_f1_score did not improve from 0.67593
# Epoch 36/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0822 - accuracy: 0.9815 - micro_f1_score: 0.9815 - macro_f1_score: 0.9760 - val_loss: 1.2736 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6128
#
# Epoch 00036: val_macro_f1_score did not improve from 0.67593
# Epoch 37/100
# 223/223 [==============================] - 9s 38ms/step - loss: 0.0921 - accuracy: 0.9796 - micro_f1_score: 0.9796 - macro_f1_score: 0.9741 - val_loss: 1.2832 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6128
#
# Epoch 00037: val_macro_f1_score did not improve from 0.67593
# Epoch 38/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0988 - accuracy: 0.9761 - micro_f1_score: 0.9761 - macro_f1_score: 0.9697 - val_loss: 1.2832 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6128
#
# Epoch 00038: val_macro_f1_score did not improve from 0.67593
# Epoch 39/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0864 - accuracy: 0.9806 - micro_f1_score: 0.9806 - macro_f1_score: 0.9750 - val_loss: 1.2887 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6162
#
# Epoch 00039: val_macro_f1_score did not improve from 0.67593
# Epoch 40/100
# 223/223 [==============================] - 8s 37ms/step - loss: 0.0808 - accuracy: 0.9829 - micro_f1_score: 0.9829 - macro_f1_score: 0.9773 - val_loss: 1.2939 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6130
#
# Epoch 00040: val_macro_f1_score did not improve from 0.67593
# Epoch 41/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0792 - accuracy: 0.9818 - micro_f1_score: 0.9818 - macro_f1_score: 0.9765 - val_loss: 1.3059 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6095
#
# Epoch 00041: val_macro_f1_score did not improve from 0.67593
# Epoch 42/100
# 223/223 [==============================] - 9s 38ms/step - loss: 0.0827 - accuracy: 0.9814 - micro_f1_score: 0.9814 - macro_f1_score: 0.9762 - val_loss: 1.3112 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6095
#
# Epoch 00042: val_macro_f1_score did not improve from 0.67593
# Epoch 43/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0921 - accuracy: 0.9792 - micro_f1_score: 0.9792 - macro_f1_score: 0.9734 - val_loss: 1.3131 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6095
#
# Epoch 00043: val_macro_f1_score did not improve from 0.67593
# Epoch 44/100
# 223/223 [==============================] - 8s 38ms/step - loss: 0.0881 - accuracy: 0.9808 - micro_f1_score: 0.9808 - macro_f1_score: 0.9748 - val_loss: 1.3173 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.6065
#
# Epoch 00044: val_macro_f1_score did not improve from 0.67593
# Epoch 45/100
# 223/223 [==============================] - 9s 38ms/step - loss: 0.0831 - accuracy: 0.9821 - micro_f1_score: 0.9821 - macro_f1_score: 0.9763 - val_loss: 1.3163 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6177
#
# Epoch 00045: val_macro_f1_score did not improve from 0.67593
# Epoch 46/100
# 223/223 [==============================] - 8s 35ms/step - loss: 0.0798 - accuracy: 0.9825 - micro_f1_score: 0.9825 - macro_f1_score: 0.9765 - val_loss: 1.3079 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6177
#
# Epoch 00046: val_macro_f1_score did not improve from 0.67593

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 1.379145447909832)

# %% [markdown]
# ##### Plot learning rate of micro F1-score and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 1.003173466026783)

# %% [markdown]
# ##### Load best hidden nodes' weight from checkpoint and predict test set

# %%
model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8116 - accuracy: 0.6835 - micro_f1_score: 0.6835 - macro_f1_score: 0.6045
# Test Loss: 0.8115994930267334
# Test Accuracy: 0.683501660823822
# Micro F1-Score: 0.683501660823822
# Macro F1-Score: 0.6044576168060303

# %% [markdown]
# #### Long-Short Term Memory (LSTM) <a class="anchor" id="lstm"></a>
#
# However, RNN can easily encounter gradient vanish or explode [(Haozheng et al., 2018)](https://github.com/NiHaozheng/NLP-Project). Hence, Long Short-Term Memory is proposed [(Sepp Hochreiter, 1997)](https://dl.acm.org/doi/10.1162/neco.1997.9.8.1735). LSTM is upgraded version of RNN with additions of output gate (o), forget gate (f) and a memory cell in RNN cell [(Xu et al., 2019)](https://ieeexplore.ieee.org/document/8684825).
#
# The LSTM network is made up of cells and gates. The cells in LSTM also called memory cell, where it stores the input or forgot irrelevant value based on training. The gates, however, control if the erase, read and write operation on memory cell. There are total three gates in LSTM network, namely input gate, forget gate and output gate.
#
# Neural network has proven by some author such as [Paliwal(et al., 2018)](https://ieeexplore.ieee.org/document/8597358) that can improve the result significantly. Long Short-Term Memory is a type of recurrent neural network (RNN) that able to learn and predict the sequence of words in a sentence. In simple word, LSTM added memory cell in RNN. LSTM is a very well-known technique in speech recognition and language translation. LSTM alone have various types of architecture, such as Vanilla LSTM which contain single LSTM layer only, which make it the simplest LSTM architecture; or Bidirectional LSTM that learned input text sequences with both forward and backward method, and there are many more types of LSTM.

# %% [markdown]
# ##### Build neural network model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix]),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network with parameters

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 30,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_basic_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 45)

# %% [markdown]
# ##### Train neural network

# %%
history = model.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 18s 67ms/step - loss: 0.9729 - accuracy: 0.6341 - micro_f1_score: 0.6341 - macro_f1_score: 0.4213 - val_loss: 0.8749 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.5072
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.50725, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.7702 - accuracy: 0.7554 - micro_f1_score: 0.7554 - macro_f1_score: 0.5496 - val_loss: 0.8289 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.5212
#
# Epoch 00002: val_macro_f1_score improved from 0.50725 to 0.52121, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.6792 - accuracy: 0.7793 - micro_f1_score: 0.7793 - macro_f1_score: 0.6295 - val_loss: 0.7697 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6176
#
# Epoch 00003: val_macro_f1_score improved from 0.52121 to 0.61757, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.5871 - accuracy: 0.8300 - micro_f1_score: 0.8300 - macro_f1_score: 0.7635 - val_loss: 0.7162 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6725
#
# Epoch 00004: val_macro_f1_score improved from 0.61757 to 0.67250, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.4944 - accuracy: 0.8644 - micro_f1_score: 0.8644 - macro_f1_score: 0.8169 - val_loss: 0.7314 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6801
#
# Epoch 00005: val_macro_f1_score improved from 0.67250 to 0.68005, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.3951 - accuracy: 0.9032 - micro_f1_score: 0.9032 - macro_f1_score: 0.8739 - val_loss: 0.7629 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6403
#
# Epoch 00006: val_macro_f1_score did not improve from 0.68005
# Epoch 7/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.3329 - accuracy: 0.9211 - micro_f1_score: 0.9211 - macro_f1_score: 0.8991 - val_loss: 0.7650 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6739
#
# Epoch 00007: val_macro_f1_score did not improve from 0.68005
# Epoch 8/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.2833 - accuracy: 0.9381 - micro_f1_score: 0.9381 - macro_f1_score: 0.9214 - val_loss: 0.7738 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6822
#
# Epoch 00008: val_macro_f1_score improved from 0.68005 to 0.68222, saving model to training_1\w2v_basic_lstm_no_emoji.ckpt
# Epoch 9/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.2375 - accuracy: 0.9481 - micro_f1_score: 0.9481 - macro_f1_score: 0.9335 - val_loss: 0.8105 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6641
#
# Epoch 00009: val_macro_f1_score did not improve from 0.68222
# Epoch 10/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.2114 - accuracy: 0.9538 - micro_f1_score: 0.9538 - macro_f1_score: 0.9414 - val_loss: 0.8717 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6787
#
# Epoch 00010: val_macro_f1_score did not improve from 0.68222
# Epoch 11/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.1738 - accuracy: 0.9652 - micro_f1_score: 0.9652 - macro_f1_score: 0.9560 - val_loss: 0.9626 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6499
#
# Epoch 00011: val_macro_f1_score did not improve from 0.68222
# Epoch 12/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.1623 - accuracy: 0.9676 - micro_f1_score: 0.9676 - macro_f1_score: 0.9578 - val_loss: 0.9235 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6725
#
# Epoch 00012: val_macro_f1_score did not improve from 0.68222
# Epoch 13/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.1442 - accuracy: 0.9727 - micro_f1_score: 0.9727 - macro_f1_score: 0.9654 - val_loss: 0.9589 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6653
#
# Epoch 00013: val_macro_f1_score did not improve from 0.68222
# Epoch 14/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.1212 - accuracy: 0.9789 - micro_f1_score: 0.9789 - macro_f1_score: 0.9740 - val_loss: 1.0000 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6596
#
# Epoch 00014: val_macro_f1_score did not improve from 0.68222
# Epoch 15/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.1164 - accuracy: 0.9783 - micro_f1_score: 0.9783 - macro_f1_score: 0.9722 - val_loss: 1.0962 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6514
#
# Epoch 00015: val_macro_f1_score did not improve from 0.68222
# Epoch 16/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.1103 - accuracy: 0.9808 - micro_f1_score: 0.9808 - macro_f1_score: 0.9756 - val_loss: 1.1031 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6703
#
# Epoch 00016: val_macro_f1_score did not improve from 0.68222
# Epoch 17/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0964 - accuracy: 0.9839 - micro_f1_score: 0.9839 - macro_f1_score: 0.9803 - val_loss: 1.1453 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6346
#
# Epoch 00017: val_macro_f1_score did not improve from 0.68222
# Epoch 18/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0933 - accuracy: 0.9838 - micro_f1_score: 0.9838 - macro_f1_score: 0.9805 - val_loss: 1.1630 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6330
#
# Epoch 00018: val_macro_f1_score did not improve from 0.68222
# Epoch 19/100
# 223/223 [==============================] - 16s 73ms/step - loss: 0.0801 - accuracy: 0.9868 - micro_f1_score: 0.9868 - macro_f1_score: 0.9842 - val_loss: 1.1588 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6304
#
# Epoch 00019: val_macro_f1_score did not improve from 0.68222
# Epoch 20/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0792 - accuracy: 0.9867 - micro_f1_score: 0.9867 - macro_f1_score: 0.9841 - val_loss: 1.1741 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6418
#
# Epoch 00020: val_macro_f1_score did not improve from 0.68222
# Epoch 21/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0748 - accuracy: 0.9869 - micro_f1_score: 0.9869 - macro_f1_score: 0.9842 - val_loss: 1.2352 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6301
#
# Epoch 00021: val_macro_f1_score did not improve from 0.68222
# Epoch 22/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0800 - accuracy: 0.9839 - micro_f1_score: 0.9839 - macro_f1_score: 0.9808 - val_loss: 1.2124 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6402
#
# Epoch 00022: val_macro_f1_score did not improve from 0.68222
# Epoch 23/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0856 - accuracy: 0.9829 - micro_f1_score: 0.9829 - macro_f1_score: 0.9790 - val_loss: 1.1950 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6706
#
# Epoch 00023: val_macro_f1_score did not improve from 0.68222
# Epoch 24/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.1046 - accuracy: 0.9791 - micro_f1_score: 0.9791 - macro_f1_score: 0.9735 - val_loss: 1.1586 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6162
#
# Epoch 00024: val_macro_f1_score did not improve from 0.68222
# Epoch 25/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0672 - accuracy: 0.9878 - micro_f1_score: 0.9878 - macro_f1_score: 0.9848 - val_loss: 1.1866 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6448
#
# Epoch 00025: val_macro_f1_score did not improve from 0.68222
# Epoch 26/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0591 - accuracy: 0.9898 - micro_f1_score: 0.9898 - macro_f1_score: 0.9876 - val_loss: 1.2427 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6327
#
# Epoch 00026: val_macro_f1_score did not improve from 0.68222
# Epoch 27/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0586 - accuracy: 0.9898 - micro_f1_score: 0.9898 - macro_f1_score: 0.9881 - val_loss: 1.2712 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6227
#
# Epoch 00027: val_macro_f1_score did not improve from 0.68222
# Epoch 28/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0551 - accuracy: 0.9909 - micro_f1_score: 0.9909 - macro_f1_score: 0.9892 - val_loss: 1.3207 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6123
#
# Epoch 00028: val_macro_f1_score did not improve from 0.68222
# Epoch 29/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0614 - accuracy: 0.9896 - micro_f1_score: 0.9896 - macro_f1_score: 0.9876 - val_loss: 1.3043 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6141
#
# Epoch 00029: val_macro_f1_score did not improve from 0.68222
# Epoch 30/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0517 - accuracy: 0.9912 - micro_f1_score: 0.9912 - macro_f1_score: 0.9894 - val_loss: 1.3458 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6022
#
# Epoch 00030: val_macro_f1_score did not improve from 0.68222
# Epoch 31/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0505 - accuracy: 0.9912 - micro_f1_score: 0.9912 - macro_f1_score: 0.9897 - val_loss: 1.3423 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.5998
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00031: val_macro_f1_score did not improve from 0.68222
# Epoch 32/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0551 - accuracy: 0.9907 - micro_f1_score: 0.9907 - macro_f1_score: 0.9888 - val_loss: 1.3507 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6082
#
# Epoch 00032: val_macro_f1_score did not improve from 0.68222
# Epoch 33/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0411 - accuracy: 0.9934 - micro_f1_score: 0.9934 - macro_f1_score: 0.9921 - val_loss: 1.3476 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6096
#
# Epoch 00033: val_macro_f1_score did not improve from 0.68222
# Epoch 34/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0527 - accuracy: 0.9908 - micro_f1_score: 0.9908 - macro_f1_score: 0.9895 - val_loss: 1.3402 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.6178
#
# Epoch 00034: val_macro_f1_score did not improve from 0.68222
# Epoch 35/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0448 - accuracy: 0.9924 - micro_f1_score: 0.9924 - macro_f1_score: 0.9915 - val_loss: 1.3433 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6205
#
# Epoch 00035: val_macro_f1_score did not improve from 0.68222
# Epoch 36/100
# 223/223 [==============================] - 16s 74ms/step - loss: 0.0518 - accuracy: 0.9912 - micro_f1_score: 0.9912 - macro_f1_score: 0.9896 - val_loss: 1.3399 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6205
#
# Epoch 00036: val_macro_f1_score did not improve from 0.68222
# Epoch 37/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0422 - accuracy: 0.9929 - micro_f1_score: 0.9929 - macro_f1_score: 0.9918 - val_loss: 1.3450 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6205
#
# Epoch 00037: val_macro_f1_score did not improve from 0.68222
# Epoch 38/100
# 223/223 [==============================] - 15s 68ms/step - loss: 0.0441 - accuracy: 0.9924 - micro_f1_score: 0.9924 - macro_f1_score: 0.9907 - val_loss: 1.3381 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.6287
#
# Epoch 00038: val_macro_f1_score did not improve from 0.68222
# Epoch 39/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0439 - accuracy: 0.9924 - micro_f1_score: 0.9924 - macro_f1_score: 0.9913 - val_loss: 1.3333 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6375
#
# Epoch 00039: val_macro_f1_score did not improve from 0.68222
# Epoch 40/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0467 - accuracy: 0.9921 - micro_f1_score: 0.9921 - macro_f1_score: 0.9905 - val_loss: 1.3328 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6462
#
# Epoch 00040: val_macro_f1_score did not improve from 0.68222
# Epoch 41/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0526 - accuracy: 0.9904 - micro_f1_score: 0.9904 - macro_f1_score: 0.9889 - val_loss: 1.3311 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6381
#
# Epoch 00041: val_macro_f1_score did not improve from 0.68222
# Epoch 42/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0397 - accuracy: 0.9933 - micro_f1_score: 0.9933 - macro_f1_score: 0.9920 - val_loss: 1.3198 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6553
#
# Epoch 00042: val_macro_f1_score did not improve from 0.68222
# Epoch 43/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0406 - accuracy: 0.9924 - micro_f1_score: 0.9924 - macro_f1_score: 0.9915 - val_loss: 1.3272 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6553
#
# Epoch 00043: val_macro_f1_score did not improve from 0.68222
# Epoch 44/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0409 - accuracy: 0.9932 - micro_f1_score: 0.9932 - macro_f1_score: 0.9918 - val_loss: 1.3376 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6295
#
# Epoch 00044: val_macro_f1_score did not improve from 0.68222
# Epoch 45/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0418 - accuracy: 0.9926 - micro_f1_score: 0.9926 - macro_f1_score: 0.9911 - val_loss: 1.3320 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6509
#
# Epoch 00045: val_macro_f1_score did not improve from 0.68222
# Epoch 46/100
# 223/223 [==============================] - 15s 67ms/step - loss: 0.0375 - accuracy: 0.9935 - micro_f1_score: 0.9935 - macro_f1_score: 0.9926 - val_loss: 1.3507 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.6180
#
# Epoch 00046: val_macro_f1_score did not improve from 0.68222

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 1.416091563925147)

# %% [markdown]
# ##### Plot micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 1.015628769993782)

# %% [markdown]
# ##### Load best weights from checkpoint and predict on test data

# %%
model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 0s 17ms/step - loss: 0.7050 - accuracy: 0.7391 - micro_f1_score: 0.7391 - macro_f1_score: 0.6816
# Test Loss: 0.7050360441207886
# Test Accuracy: 0.7390572428703308
# Micro F1-Score: 0.739057183265686
# Macro F1-Score: 0.6816102862358093

# %% [markdown]
# ## One Layer biLSTM

# %% [markdown]
# #### Bidirectional Long-Short Term Memory (biLSTM) <a class="anchor" id="bilstm"></a>
#
# Another program arise when using LSTM is that the neural network is able to learn text sequence in forward direction only (Xu et al., 2019). Hence bidirectional-LSTM (biLSTM) is proposed by authors ([Du et al., 2020](https://iopscience.iop.org/article/10.1088/1755-1315/440/3/032115); [(Xu et al., 2019)](https://ieeexplore.ieee.org/document/8684825)). With biLSTM, neural network is able to capture pattern of text in forward and backward direction.
# Unlike LSTM, biLSTM (bidirectional Long Short-Term Memory) have two later of LSTM hidden layer as in Figure 2.4 biLSTM illustration by [Xu(et al., 2019)](https://ieeexplore.ieee.org/document/8684825). In other words, it is a bidirectional RNN with LSTM units. One layer of LSTM take fed input sequence in forward order while another fed input sequence to neural network in backward order. By feeding data in two directions, model can capture surrounding inputs better and learn faster than LSTM.

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network model

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### View summary of neural network architecture

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 128)          1571968
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,679,235
# Trainable params: 1,679,235
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 20,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 30)

# %% [markdown]
# ##### Train neural network

# %%
history = model.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 28s 105ms/step - loss: 1123.6333 - accuracy: 0.6518 - micro_f1_score: 0.6518 - macro_f1_score: 0.4273 - val_loss: 658.9595 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.5033
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.50330, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 21s 92ms/step - loss: 577.0375 - accuracy: 0.7410 - micro_f1_score: 0.7410 - macro_f1_score: 0.5408 - val_loss: 388.2880 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5172
#
# Epoch 00002: val_macro_f1_score improved from 0.50330 to 0.51722, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 22s 100ms/step - loss: 346.7240 - accuracy: 0.7564 - micro_f1_score: 0.7564 - macro_f1_score: 0.5521 - val_loss: 245.2467 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.5229
#
# Epoch 00003: val_macro_f1_score improved from 0.51722 to 0.52286, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 20s 88ms/step - loss: 221.0119 - accuracy: 0.7446 - micro_f1_score: 0.7446 - macro_f1_score: 0.5446 - val_loss: 160.3321 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5345
#
# Epoch 00004: val_macro_f1_score improved from 0.52286 to 0.53446, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 25s 112ms/step - loss: 145.1638 - accuracy: 0.7605 - micro_f1_score: 0.7605 - macro_f1_score: 0.5914 - val_loss: 106.8806 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6151
#
# Epoch 00005: val_macro_f1_score improved from 0.53446 to 0.61510, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 25s 112ms/step - loss: 97.0183 - accuracy: 0.7784 - micro_f1_score: 0.7784 - macro_f1_score: 0.6425 - val_loss: 72.1341 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6189
#
# Epoch 00006: val_macro_f1_score improved from 0.61510 to 0.61888, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 7/100
# 223/223 [==============================] - 25s 111ms/step - loss: 65.5599 - accuracy: 0.7763 - micro_f1_score: 0.7763 - macro_f1_score: 0.6521 - val_loss: 49.0487 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.5983
#
# Epoch 00007: val_macro_f1_score did not improve from 0.61888
# Epoch 8/100
# 223/223 [==============================] - 25s 111ms/step - loss: 44.5870 - accuracy: 0.7754 - micro_f1_score: 0.7754 - macro_f1_score: 0.6787 - val_loss: 33.5386 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6236
#
# Epoch 00008: val_macro_f1_score improved from 0.61888 to 0.62362, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 9/100
# 223/223 [==============================] - 26s 117ms/step - loss: 30.4185 - accuracy: 0.7969 - micro_f1_score: 0.7969 - macro_f1_score: 0.6901 - val_loss: 22.9891 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6405
#
# Epoch 00009: val_macro_f1_score improved from 0.62362 to 0.64046, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 10/100
# 223/223 [==============================] - 25s 112ms/step - loss: 20.8522 - accuracy: 0.7857 - micro_f1_score: 0.7857 - macro_f1_score: 0.6983 - val_loss: 15.8758 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6084
#
# Epoch 00010: val_macro_f1_score did not improve from 0.64046
# Epoch 11/100
# 223/223 [==============================] - 25s 112ms/step - loss: 14.3436 - accuracy: 0.7762 - micro_f1_score: 0.7762 - macro_f1_score: 0.6789 - val_loss: 11.0100 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.5989
#
# Epoch 00011: val_macro_f1_score did not improve from 0.64046
# Epoch 12/100
# 223/223 [==============================] - 25s 113ms/step - loss: 9.8884 - accuracy: 0.7891 - micro_f1_score: 0.7891 - macro_f1_score: 0.7053 - val_loss: 7.6962 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6124
#
# Epoch 00012: val_macro_f1_score did not improve from 0.64046
# Epoch 13/100
# 223/223 [==============================] - 25s 111ms/step - loss: 6.8810 - accuracy: 0.7840 - micro_f1_score: 0.7840 - macro_f1_score: 0.6899 - val_loss: 5.4264 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6621
#
# Epoch 00013: val_macro_f1_score improved from 0.64046 to 0.66212, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 14/100
# 223/223 [==============================] - 25s 112ms/step - loss: 4.8262 - accuracy: 0.7898 - micro_f1_score: 0.7898 - macro_f1_score: 0.7052 - val_loss: 3.9413 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6054
#
# Epoch 00014: val_macro_f1_score did not improve from 0.66212
# Epoch 15/100
# 223/223 [==============================] - 24s 109ms/step - loss: 3.4428 - accuracy: 0.7981 - micro_f1_score: 0.7981 - macro_f1_score: 0.7202 - val_loss: 2.9298 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6261
#
# Epoch 00015: val_macro_f1_score did not improve from 0.66212
# Epoch 16/100
# 223/223 [==============================] - 25s 114ms/step - loss: 2.5315 - accuracy: 0.7980 - micro_f1_score: 0.7980 - macro_f1_score: 0.7202 - val_loss: 2.2398 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5979
#
# Epoch 00016: val_macro_f1_score did not improve from 0.66212
# Epoch 17/100
# 223/223 [==============================] - 24s 109ms/step - loss: 1.9142 - accuracy: 0.7958 - micro_f1_score: 0.7958 - macro_f1_score: 0.7228 - val_loss: 1.7597 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6235
#
# Epoch 00017: val_macro_f1_score did not improve from 0.66212
# Epoch 18/100
# 223/223 [==============================] - 24s 109ms/step - loss: 1.4840 - accuracy: 0.8104 - micro_f1_score: 0.8104 - macro_f1_score: 0.7439 - val_loss: 1.4643 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6480
#
# Epoch 00018: val_macro_f1_score did not improve from 0.66212
# Epoch 19/100
# 223/223 [==============================] - 24s 110ms/step - loss: 1.2076 - accuracy: 0.8188 - micro_f1_score: 0.8188 - macro_f1_score: 0.7639 - val_loss: 1.2704 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6320
#
# Epoch 00019: val_macro_f1_score did not improve from 0.66212
# Epoch 20/100
# 223/223 [==============================] - 24s 108ms/step - loss: 1.0406 - accuracy: 0.8043 - micro_f1_score: 0.8043 - macro_f1_score: 0.7383 - val_loss: 1.1629 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6858
#
# Epoch 00020: val_macro_f1_score improved from 0.66212 to 0.68576, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 21/100
# 223/223 [==============================] - 25s 110ms/step - loss: 0.8877 - accuracy: 0.8320 - micro_f1_score: 0.8320 - macro_f1_score: 0.7734 - val_loss: 1.1120 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.5854
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00021: val_macro_f1_score did not improve from 0.68576
# Epoch 22/100
# 223/223 [==============================] - 24s 109ms/step - loss: 0.7373 - accuracy: 0.8718 - micro_f1_score: 0.8718 - macro_f1_score: 0.8275 - val_loss: 0.9862 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6181
#
# Epoch 00022: val_macro_f1_score did not improve from 0.68576
# Epoch 23/100
# 223/223 [==============================] - 24s 109ms/step - loss: 0.6232 - accuracy: 0.8989 - micro_f1_score: 0.8989 - macro_f1_score: 0.8690 - val_loss: 0.9397 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6403
#
# Epoch 00023: val_macro_f1_score did not improve from 0.68576
# Epoch 24/100
# 223/223 [==============================] - 24s 109ms/step - loss: 0.5566 - accuracy: 0.9185 - micro_f1_score: 0.9185 - macro_f1_score: 0.8930 - val_loss: 0.9487 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6420
# Epoch 00024: val_macro_f1_score did not improve from 0.68576
# Epoch 25/100
# 223/223 [==============================] - 24s 109ms/step - loss: 0.5199 - accuracy: 0.9248 - micro_f1_score: 0.9248 - macro_f1_score: 0.9009 - val_loss: 0.9435 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6191
#
# Epoch 00025: val_macro_f1_score did not improve from 0.68576
# Epoch 26/100
# 223/223 [==============================] - 24s 109ms/step - loss: 0.4830 - accuracy: 0.9361 - micro_f1_score: 0.9361 - macro_f1_score: 0.9173 - val_loss: 0.9372 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6412
#
# Epoch 00026: val_macro_f1_score did not improve from 0.68576
# Epoch 27/100
# 223/223 [==============================] - 26s 116ms/step - loss: 0.4611 - accuracy: 0.9363 - micro_f1_score: 0.9363 - macro_f1_score: 0.9199 - val_loss: 0.9344 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6650
#
# Epoch 00027: val_macro_f1_score did not improve from 0.68576
# Epoch 28/100
# 223/223 [==============================] - 24s 110ms/step - loss: 0.4422 - accuracy: 0.9443 - micro_f1_score: 0.9443 - macro_f1_score: 0.9305 - val_loss: 0.9913 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6235
#
# Epoch 00028: val_macro_f1_score did not improve from 0.68576
# Epoch 29/100
# 223/223 [==============================] - 26s 115ms/step - loss: 0.4180 - accuracy: 0.9480 - micro_f1_score: 0.9480 - macro_f1_score: 0.9347 - val_loss: 0.9707 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6332
#
# Epoch 00029: val_macro_f1_score did not improve from 0.68576
# Epoch 30/100
# 223/223 [==============================] - 26s 115ms/step - loss: 0.3966 - accuracy: 0.9517 - micro_f1_score: 0.9517 - macro_f1_score: 0.9380 - val_loss: 0.9846 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6523
#
# Epoch 00030: val_macro_f1_score did not improve from 0.68576
# Epoch 31/100
# 223/223 [==============================] - 27s 120ms/step - loss: 0.3624 - accuracy: 0.9614 - micro_f1_score: 0.9614 - macro_f1_score: 0.9521 - val_loss: 1.0347 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6109
#
# Epoch 00031: val_macro_f1_score did not improve from 0.68576

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.6899143099785)

# %% [markdown]
# ##### Plot learning rate of micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9677955836057663)

# %% [markdown]
# ##### Load best weights of each node and predict test data

# %%
#model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 0s 21ms/step - loss: 0.8350 - accuracy: 0.7525 - micro_f1_score: 0.7525 - macro_f1_score: 0.6869
# Test Loss: 0.8349677920341492
# Test Accuracy: 0.752525269985199
# Micro F1-Score: 0.7525252103805542
# Macro F1-Score: 0.686890184879303

# %%
model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 0s 21ms/step - loss: 1.0460 - accuracy: 0.7525 - micro_f1_score: 0.7525 - macro_f1_score: 0.6844
# Test Loss: 1.0459887981414795
# Test Accuracy: 0.752525269985199
# Micro F1-Score: 0.7525252103805542
# Macro F1-Score: 0.684448778629303

# %% [markdown]
# #### Two Layer Bidirectional Long-Short Term Memory (biLSTM) <a class="anchor" id="two_bilstm"></a>
#
# [Machine Learning Mastery](https://machinelearningmastery.com/regression-tutorial-keras-deep-learning-library-python/):
# > One way to improve the performance a neural network is to add more layers. This might allow the model to extract and recombine higher order features embedded in the data.

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network model with parameters

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### View summary architecture of neural network model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 128)          1571968
# _________________________________________________________________
# bidirectional (Bidirectional (None, 100, 128)          98816
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,716,355
# Trainable params: 1,716,355
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 30,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 45)

# %% [markdown]
# ##### Train neural network

# %%
history = model.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 50s 179ms/step - loss: 1123.6527 - accuracy: 0.6340 - micro_f1_score: 0.6340 - macro_f1_score: 0.4043 - val_loss: 658.9799 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.5062
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.50618, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 33s 149ms/step - loss: 577.0507 - accuracy: 0.7494 - micro_f1_score: 0.7494 - macro_f1_score: 0.5412 - val_loss: 388.3022 - val_accuracy: 0.6548 - val_micro_f1_score: 0.6548 - val_macro_f1_score: 0.4954
#
# Epoch 00002: val_macro_f1_score did not improve from 0.50618
# Epoch 3/100
# 223/223 [==============================] - 31s 140ms/step - loss: 346.7471 - accuracy: 0.7448 - micro_f1_score: 0.7448 - macro_f1_score: 0.5495 - val_loss: 245.2576 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5129
#
# Epoch 00003: val_macro_f1_score improved from 0.50618 to 0.51295, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 30s 135ms/step - loss: 221.0274 - accuracy: 0.7528 - micro_f1_score: 0.7528 - macro_f1_score: 0.5903 - val_loss: 160.3394 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6148
#
# Epoch 00004: val_macro_f1_score improved from 0.51295 to 0.61477, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 31s 139ms/step - loss: 145.1980 - accuracy: 0.7624 - micro_f1_score: 0.7624 - macro_f1_score: 0.6583 - val_loss: 106.8898 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6462
#
# Epoch 00005: val_macro_f1_score improved from 0.61477 to 0.64615, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 30s 134ms/step - loss: 97.0454 - accuracy: 0.7846 - micro_f1_score: 0.7846 - macro_f1_score: 0.6890 - val_loss: 72.1374 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5963
#
# Epoch 00006: val_macro_f1_score did not improve from 0.64615
# Epoch 7/100
# 223/223 [==============================] - 30s 136ms/step - loss: 65.5828 - accuracy: 0.7811 - micro_f1_score: 0.7811 - macro_f1_score: 0.6840 - val_loss: 49.0877 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5945
#
# Epoch 00007: val_macro_f1_score did not improve from 0.64615
# Epoch 8/100
# 223/223 [==============================] - 30s 135ms/step - loss: 44.5960 - accuracy: 0.7827 - micro_f1_score: 0.7827 - macro_f1_score: 0.6864 - val_loss: 33.5422 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6293
#
# Epoch 00008: val_macro_f1_score did not improve from 0.64615
# Epoch 9/100
# 223/223 [==============================] - 30s 135ms/step - loss: 30.4559 - accuracy: 0.7820 - micro_f1_score: 0.7820 - macro_f1_score: 0.6903 - val_loss: 23.0006 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6361
#
# Epoch 00009: val_macro_f1_score did not improve from 0.64615
# Epoch 10/100
# 223/223 [==============================] - 30s 133ms/step - loss: 20.8694 - accuracy: 0.7890 - micro_f1_score: 0.7890 - macro_f1_score: 0.7102 - val_loss: 15.9008 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6457
#
# Epoch 00010: val_macro_f1_score did not improve from 0.64615
# Epoch 11/100
# 223/223 [==============================] - 30s 136ms/step - loss: 14.3431 - accuracy: 0.7937 - micro_f1_score: 0.7937 - macro_f1_score: 0.7175 - val_loss: 11.0078 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6241
#
# Epoch 00011: val_macro_f1_score did not improve from 0.64615
# Epoch 12/100
# 223/223 [==============================] - 30s 134ms/step - loss: 9.9003 - accuracy: 0.7879 - micro_f1_score: 0.7879 - macro_f1_score: 0.7084 - val_loss: 7.7331 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6307
#
# Epoch 00012: val_macro_f1_score did not improve from 0.64615
# Epoch 13/100
# 223/223 [==============================] - 30s 134ms/step - loss: 6.9100 - accuracy: 0.7890 - micro_f1_score: 0.7890 - macro_f1_score: 0.7069 - val_loss: 5.4601 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6635
#
# Epoch 00013: val_macro_f1_score improved from 0.64615 to 0.66349, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 14/100
# 223/223 [==============================] - 30s 136ms/step - loss: 4.8208 - accuracy: 0.8117 - micro_f1_score: 0.8117 - macro_f1_score: 0.7468 - val_loss: 4.0040 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6015
#
# Epoch 00014: val_macro_f1_score did not improve from 0.66349
# Epoch 15/100
# 223/223 [==============================] - 30s 134ms/step - loss: 3.4575 - accuracy: 0.8093 - micro_f1_score: 0.8093 - macro_f1_score: 0.7379 - val_loss: 2.9031 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6516
#
# Epoch 00015: val_macro_f1_score did not improve from 0.66349
# Epoch 16/100
# 223/223 [==============================] - 30s 136ms/step - loss: 2.5298 - accuracy: 0.8120 - micro_f1_score: 0.8120 - macro_f1_score: 0.7473 - val_loss: 2.2461 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6160
#
# Epoch 00016: val_macro_f1_score did not improve from 0.66349
# Epoch 17/100
# 223/223 [==============================] - 33s 149ms/step - loss: 1.9008 - accuracy: 0.8199 - micro_f1_score: 0.8199 - macro_f1_score: 0.7480 - val_loss: 1.8162 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6499
#
# Epoch 00017: val_macro_f1_score did not improve from 0.66349
# Epoch 18/100
# 223/223 [==============================] - 32s 142ms/step - loss: 1.5137 - accuracy: 0.8133 - micro_f1_score: 0.8133 - macro_f1_score: 0.7503 - val_loss: 1.4622 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6651
#
# Epoch 00018: val_macro_f1_score improved from 0.66349 to 0.66514, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 19/100
# 223/223 [==============================] - 31s 140ms/step - loss: 1.2035 - accuracy: 0.8339 - micro_f1_score: 0.8339 - macro_f1_score: 0.7818 - val_loss: 1.3141 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6599
#
# Epoch 00019: val_macro_f1_score did not improve from 0.66514
# Epoch 20/100
# 223/223 [==============================] - 32s 145ms/step - loss: 1.0067 - accuracy: 0.8420 - micro_f1_score: 0.8420 - macro_f1_score: 0.7956 - val_loss: 1.2291 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6105
#
# Epoch 00020: val_macro_f1_score did not improve from 0.66514
# Epoch 21/100
# 223/223 [==============================] - 32s 142ms/step - loss: 0.8836 - accuracy: 0.8494 - micro_f1_score: 0.8494 - macro_f1_score: 0.8032 - val_loss: 1.0590 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6810
#
# Epoch 00021: val_macro_f1_score improved from 0.66514 to 0.68104, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 22/100
# 223/223 [==============================] - 31s 140ms/step - loss: 0.7598 - accuracy: 0.8680 - micro_f1_score: 0.8680 - macro_f1_score: 0.8229 - val_loss: 0.9886 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6841
#
# Epoch 00022: val_macro_f1_score improved from 0.68104 to 0.68409, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 23/100
# 223/223 [==============================] - 33s 146ms/step - loss: 0.6761 - accuracy: 0.8731 - micro_f1_score: 0.8731 - macro_f1_score: 0.8343 - val_loss: 1.0397 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6414
#
# Epoch 00023: val_macro_f1_score did not improve from 0.68409
# Epoch 24/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.6386 - accuracy: 0.8852 - micro_f1_score: 0.8852 - macro_f1_score: 0.8474 - val_loss: 0.9799 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6456
#
# Epoch 00024: val_macro_f1_score did not improve from 0.68409
# Epoch 25/100
# 223/223 [==============================] - 36s 163ms/step - loss: 0.5762 - accuracy: 0.8936 - micro_f1_score: 0.8936 - macro_f1_score: 0.8602 - val_loss: 0.9979 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6478
#
# Epoch 00025: val_macro_f1_score did not improve from 0.68409
# Epoch 26/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.5589 - accuracy: 0.9008 - micro_f1_score: 0.9008 - macro_f1_score: 0.8715 - val_loss: 0.9715 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6599
#
# Epoch 00026: val_macro_f1_score did not improve from 0.68409
# Epoch 27/100
# 223/223 [==============================] - 29s 132ms/step - loss: 0.5368 - accuracy: 0.8977 - micro_f1_score: 0.8977 - macro_f1_score: 0.8674 - val_loss: 0.9692 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6725
#
# Epoch 00027: val_macro_f1_score did not improve from 0.68409
# Epoch 28/100
# 223/223 [==============================] - 29s 132ms/step - loss: 0.5004 - accuracy: 0.9163 - micro_f1_score: 0.9163 - macro_f1_score: 0.8924 - val_loss: 1.0212 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6616
#
# Epoch 00028: val_macro_f1_score did not improve from 0.68409
# Epoch 29/100
# 223/223 [==============================] - 29s 131ms/step - loss: 0.5010 - accuracy: 0.9145 - micro_f1_score: 0.9145 - macro_f1_score: 0.8870 - val_loss: 1.0248 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6730
#
# Epoch 00029: val_macro_f1_score did not improve from 0.68409
# Epoch 30/100
# 223/223 [==============================] - 29s 131ms/step - loss: 0.4612 - accuracy: 0.9283 - micro_f1_score: 0.9283 - macro_f1_score: 0.9067 - val_loss: 1.0331 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.6809
#
# Epoch 00030: val_macro_f1_score did not improve from 0.68409
# Epoch 31/100
# 223/223 [==============================] - 29s 131ms/step - loss: 0.4601 - accuracy: 0.9290 - micro_f1_score: 0.9290 - macro_f1_score: 0.9073 - val_loss: 1.0186 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.6999
#
# Epoch 00031: val_macro_f1_score improved from 0.68409 to 0.69993, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 32/100
# 223/223 [==============================] - 29s 132ms/step - loss: 0.4645 - accuracy: 0.9243 - micro_f1_score: 0.9243 - macro_f1_score: 0.8983 - val_loss: 1.1189 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6675
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00032: val_macro_f1_score did not improve from 0.69993
# Epoch 33/100
# 223/223 [==============================] - 29s 131ms/step - loss: 0.4479 - accuracy: 0.9377 - micro_f1_score: 0.9377 - macro_f1_score: 0.9170 - val_loss: 1.0223 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6774
#
# Epoch 00033: val_macro_f1_score did not improve from 0.69993
# Epoch 34/100
# 223/223 [==============================] - 29s 131ms/step - loss: 0.3263 - accuracy: 0.9661 - micro_f1_score: 0.9661 - macro_f1_score: 0.9552 - val_loss: 1.0061 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6774
#
# Epoch 00034: val_macro_f1_score did not improve from 0.69993
# Epoch 35/100
# 223/223 [==============================] - 30s 133ms/step - loss: 0.3041 - accuracy: 0.9671 - micro_f1_score: 0.9671 - macro_f1_score: 0.9576 - val_loss: 1.0054 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6828
#
# Epoch 00035: val_macro_f1_score did not improve from 0.69993
# Epoch 36/100
# 223/223 [==============================] - 30s 133ms/step - loss: 0.2782 - accuracy: 0.9689 - micro_f1_score: 0.9689 - macro_f1_score: 0.9601 - val_loss: 1.0223 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6779
#
# Epoch 00036: val_macro_f1_score did not improve from 0.69993
# Epoch 37/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.2464 - accuracy: 0.9761 - micro_f1_score: 0.9761 - macro_f1_score: 0.9692 - val_loss: 1.0317 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6696
#
# Epoch 00037: val_macro_f1_score did not improve from 0.69993
# Epoch 38/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.2304 - accuracy: 0.9772 - micro_f1_score: 0.9772 - macro_f1_score: 0.9717 - val_loss: 1.0294 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6733
#
# Epoch 00038: val_macro_f1_score did not improve from 0.69993
# Epoch 39/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.2159 - accuracy: 0.9776 - micro_f1_score: 0.9776 - macro_f1_score: 0.9717 - val_loss: 1.0292 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6812
#
# Epoch 00039: val_macro_f1_score did not improve from 0.69993
# Epoch 40/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.2113 - accuracy: 0.9765 - micro_f1_score: 0.9765 - macro_f1_score: 0.9693 - val_loss: 1.0373 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6733
#
# Epoch 00040: val_macro_f1_score did not improve from 0.69993
# Epoch 41/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1952 - accuracy: 0.9794 - micro_f1_score: 0.9794 - macro_f1_score: 0.9750 - val_loss: 1.0432 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6785
#
# Epoch 00041: val_macro_f1_score did not improve from 0.69993
# Epoch 42/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1961 - accuracy: 0.9768 - micro_f1_score: 0.9768 - macro_f1_score: 0.9701 - val_loss: 1.0375 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6737
#
# Epoch 00042: val_macro_f1_score did not improve from 0.69993
# Epoch 43/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1985 - accuracy: 0.9754 - micro_f1_score: 0.9754 - macro_f1_score: 0.9689 - val_loss: 1.0428 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6774
#
# Epoch 00043: val_macro_f1_score did not improve from 0.69993
# Epoch 44/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1701 - accuracy: 0.9822 - micro_f1_score: 0.9822 - macro_f1_score: 0.9776 - val_loss: 1.0654 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6682
#
# Epoch 00044: val_macro_f1_score did not improve from 0.69993
# Epoch 45/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1789 - accuracy: 0.9783 - micro_f1_score: 0.9783 - macro_f1_score: 0.9725 - val_loss: 1.0356 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6893
#
# Epoch 00045: val_macro_f1_score did not improve from 0.69993
# Epoch 46/100
# 223/223 [==============================] - 29s 130ms/step - loss: 0.1670 - accuracy: 0.9806 - micro_f1_score: 0.9806 - macro_f1_score: 0.9760 - val_loss: 1.0515 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6857
#
# Epoch 00046: val_macro_f1_score did not improve from 0.69993
# Epoch 47/100
# 223/223 [==============================] - 30s 134ms/step - loss: 0.1677 - accuracy: 0.9794 - micro_f1_score: 0.9794 - macro_f1_score: 0.9743 - val_loss: 1.0718 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6597
#
# Epoch 00047: val_macro_f1_score did not improve from 0.69993

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.7233821950853)

# %% [markdown]
# ##### Plot learning rate of micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9981924206018448)

# %%
#model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 31ms/step - loss: 0.9996 - accuracy: 0.7441 - micro_f1_score: 0.7441 - macro_f1_score: 0.6854
# Test Loss: 0.99962317943573
# Test Accuracy: 0.744107723236084
# Micro F1-Score: 0.7441076636314392
# Macro F1-Score: 0.6853858828544617

# %% [markdown]
# ##### Load best weights of hidden nodes and predict test data

# %%
model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 31ms/step - loss: 0.9913 - accuracy: 0.7374 - micro_f1_score: 0.7374 - macro_f1_score: 0.6680
# Test Loss: 0.9912955164909363
# Test Accuracy: 0.7373737096786499
# Micro F1-Score: 0.7373737096786499
# Macro F1-Score: 0.6680322289466858

# %% [markdown]
# #### Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.2 <a class="anchor" id="two_bilstm_02"></a>
#
# Dropout is a types of regularization that ignore some nodes randomly in training, which changed the architecture of neural network with just a layer of dropout added [(Garbin & Zhu, 2020)](https://link.springer.com/article/10.1007/s11042-019-08453-9). With additional dropout added, training time will be increased [(Garbin & Zhu, 2020)](https://link.springer.com/article/10.1007/s11042-019-08453-9).

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model_02 = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network

# %%
model_02.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### View summary architecture of neural network model

# %%
model_02.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 128)          1571968
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 100, 128)          98816
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,716,355
# Trainable params: 1,716,355
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 40,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 50)

# %% [markdown]
# ##### Train neural network

# %%
history_02 = model_02.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 53s 178ms/step - loss: 1123.6518 - accuracy: 0.6255 - micro_f1_score: 0.6255 - macro_f1_score: 0.3832 - val_loss: 658.9908 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.4960
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.49605, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 36s 161ms/step - loss: 577.0648 - accuracy: 0.7412 - micro_f1_score: 0.7412 - macro_f1_score: 0.5368 - val_loss: 388.3213 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5141
#
# Epoch 00002: val_macro_f1_score improved from 0.49605 to 0.51411, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 36s 162ms/step - loss: 346.7549 - accuracy: 0.7527 - micro_f1_score: 0.7527 - macro_f1_score: 0.5452 - val_loss: 245.2739 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.5137
#
# Epoch 00003: val_macro_f1_score did not improve from 0.51411
# Epoch 4/100
# 223/223 [==============================] - 38s 171ms/step - loss: 221.0491 - accuracy: 0.7409 - micro_f1_score: 0.7409 - macro_f1_score: 0.5457 - val_loss: 160.3677 - val_accuracy: 0.6701 - val_micro_f1_score: 0.6701 - val_macro_f1_score: 0.5135
#
# Epoch 00004: val_macro_f1_score did not improve from 0.51411
# Epoch 5/100
# 223/223 [==============================] - 37s 167ms/step - loss: 145.2324 - accuracy: 0.7464 - micro_f1_score: 0.7464 - macro_f1_score: 0.5977 - val_loss: 106.9497 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5638
#
# Epoch 00005: val_macro_f1_score improved from 0.51411 to 0.56377, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 40s 178ms/step - loss: 97.1083 - accuracy: 0.7544 - micro_f1_score: 0.7544 - macro_f1_score: 0.6484 - val_loss: 72.1730 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5776
#
# Epoch 00006: val_macro_f1_score improved from 0.56377 to 0.57755, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 7/100
# 223/223 [==============================] - 37s 164ms/step - loss: 65.6200 - accuracy: 0.7643 - micro_f1_score: 0.7643 - macro_f1_score: 0.6532 - val_loss: 49.1107 - val_accuracy: 0.6497 - val_micro_f1_score: 0.6497 - val_macro_f1_score: 0.6024
#
# Epoch 00007: val_macro_f1_score improved from 0.57755 to 0.60240, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 8/100
# 223/223 [==============================] - 37s 167ms/step - loss: 44.6221 - accuracy: 0.7753 - micro_f1_score: 0.7753 - macro_f1_score: 0.6917 - val_loss: 33.5989 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5805
#
# Epoch 00008: val_macro_f1_score did not improve from 0.60240
# Epoch 9/100
# 223/223 [==============================] - 38s 169ms/step - loss: 30.4985 - accuracy: 0.7685 - micro_f1_score: 0.7685 - macro_f1_score: 0.6693 - val_loss: 23.0442 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6041
#
# Epoch 00009: val_macro_f1_score improved from 0.60240 to 0.60406, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 10/100
# 223/223 [==============================] - 36s 160ms/step - loss: 20.9166 - accuracy: 0.7671 - micro_f1_score: 0.7671 - macro_f1_score: 0.6782 - val_loss: 15.9018 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5922
#
# Epoch 00010: val_macro_f1_score did not improve from 0.60406
# Epoch 11/100
# 223/223 [==============================] - 39s 177ms/step - loss: 14.3592 - accuracy: 0.7871 - micro_f1_score: 0.7871 - macro_f1_score: 0.7085 - val_loss: 11.0031 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6457
#
# Epoch 00011: val_macro_f1_score improved from 0.60406 to 0.64567, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 12/100
# 223/223 [==============================] - 40s 180ms/step - loss: 9.9362 - accuracy: 0.7812 - micro_f1_score: 0.7812 - macro_f1_score: 0.6943 - val_loss: 7.7174 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5888
#
# Epoch 00012: val_macro_f1_score did not improve from 0.64567
# Epoch 13/100
# 223/223 [==============================] - 37s 164ms/step - loss: 6.8870 - accuracy: 0.7911 - micro_f1_score: 0.7911 - macro_f1_score: 0.7041 - val_loss: 5.5302 - val_accuracy: 0.6345 - val_micro_f1_score: 0.6345 - val_macro_f1_score: 0.5665
#
# Epoch 00013: val_macro_f1_score did not improve from 0.64567
# Epoch 14/100
# 223/223 [==============================] - 37s 165ms/step - loss: 4.8569 - accuracy: 0.7863 - micro_f1_score: 0.7863 - macro_f1_score: 0.7148 - val_loss: 3.9395 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6527
#
# Epoch 00014: val_macro_f1_score improved from 0.64567 to 0.65270, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 15/100
# 223/223 [==============================] - 36s 162ms/step - loss: 3.4575 - accuracy: 0.7984 - micro_f1_score: 0.7984 - macro_f1_score: 0.7312 - val_loss: 2.9516 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6311
#
# Epoch 00015: val_macro_f1_score did not improve from 0.65270
# Epoch 16/100
# 223/223 [==============================] - 35s 158ms/step - loss: 2.5604 - accuracy: 0.7971 - micro_f1_score: 0.7971 - macro_f1_score: 0.7289 - val_loss: 2.2169 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6125
#
# Epoch 00016: val_macro_f1_score did not improve from 0.65270
# Epoch 17/100
# 223/223 [==============================] - 34s 152ms/step - loss: 1.9195 - accuracy: 0.8025 - micro_f1_score: 0.8025 - macro_f1_score: 0.7356 - val_loss: 1.7746 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6376
#
# Epoch 00017: val_macro_f1_score did not improve from 0.65270
# Epoch 18/100
# 223/223 [==============================] - 36s 159ms/step - loss: 1.5038 - accuracy: 0.8102 - micro_f1_score: 0.8102 - macro_f1_score: 0.7492 - val_loss: 1.5008 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.5898
#
# Epoch 00018: val_macro_f1_score did not improve from 0.65270
# Epoch 19/100
# 223/223 [==============================] - 39s 174ms/step - loss: 1.2055 - accuracy: 0.8207 - micro_f1_score: 0.8207 - macro_f1_score: 0.7592 - val_loss: 1.3197 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.5971
#
# Epoch 00019: val_macro_f1_score did not improve from 0.65270
# Epoch 20/100
# 223/223 [==============================] - 35s 155ms/step - loss: 1.0159 - accuracy: 0.8280 - micro_f1_score: 0.8280 - macro_f1_score: 0.7664 - val_loss: 1.1589 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6619
#
# Epoch 00020: val_macro_f1_score improved from 0.65270 to 0.66186, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 21/100
# 223/223 [==============================] - 39s 174ms/step - loss: 0.8492 - accuracy: 0.8539 - micro_f1_score: 0.8539 - macro_f1_score: 0.8018 - val_loss: 1.0368 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.6919
#
# Epoch 00021: val_macro_f1_score improved from 0.66186 to 0.69192, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 22/100
# 223/223 [==============================] - 40s 179ms/step - loss: 0.7578 - accuracy: 0.8618 - micro_f1_score: 0.8618 - macro_f1_score: 0.8137 - val_loss: 1.0088 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6358
#
# Epoch 00022: val_macro_f1_score did not improve from 0.69192
# Epoch 23/100
# 223/223 [==============================] - 38s 168ms/step - loss: 0.7213 - accuracy: 0.8466 - micro_f1_score: 0.8466 - macro_f1_score: 0.7978 - val_loss: 1.0090 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6729470 - micro
#
# Epoch 00023: val_macro_f1_score did not improve from 0.69192
# Epoch 24/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.6365 - accuracy: 0.8679 - micro_f1_score: 0.8679 - macro_f1_score: 0.8219 - val_loss: 0.8994 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6539
# Epoch 00024: val_macro_f1_score did not improve from 0.69192
# Epoch 25/100
# 223/223 [==============================] - 33s 149ms/step - loss: 0.5763 - accuracy: 0.8858 - micro_f1_score: 0.8858 - macro_f1_score: 0.8505 - val_loss: 0.9080 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7131
#
# Epoch 00025: val_macro_f1_score improved from 0.69192 to 0.71311, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 26/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.5590 - accuracy: 0.8890 - micro_f1_score: 0.8890 - macro_f1_score: 0.8526 - val_loss: 0.8463 - val_accuracy: 0.7716 - val_micro_f1_score: 0.7716 - val_macro_f1_score: 0.7215
#
# Epoch 00026: val_macro_f1_score improved from 0.71311 to 0.72155, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 27/100
# 223/223 [==============================] - 34s 150ms/step - loss: 0.5392 - accuracy: 0.8938 - micro_f1_score: 0.8938 - macro_f1_score: 0.8637 - val_loss: 1.0106 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.6724
#
# Epoch 00027: val_macro_f1_score did not improve from 0.72155
# Epoch 28/100
# 223/223 [==============================] - 33s 149ms/step - loss: 0.5061 - accuracy: 0.9105 - micro_f1_score: 0.9105 - macro_f1_score: 0.8842 - val_loss: 0.9579 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6723
#
# Epoch 00028: val_macro_f1_score did not improve from 0.72155
# Epoch 29/100
# 223/223 [==============================] - 34s 150ms/step - loss: 0.5132 - accuracy: 0.9024 - micro_f1_score: 0.9024 - macro_f1_score: 0.8755 - val_loss: 0.9306 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7166
#
# Epoch 00029: val_macro_f1_score did not improve from 0.72155
# Epoch 30/100
# 223/223 [==============================] - 33s 149ms/step - loss: 0.5021 - accuracy: 0.9063 - micro_f1_score: 0.9063 - macro_f1_score: 0.8782 - val_loss: 0.9546 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7278
#
# Epoch 00030: val_macro_f1_score improved from 0.72155 to 0.72783, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 31/100
# 223/223 [==============================] - 39s 173ms/step - loss: 0.4539 - accuracy: 0.9275 - micro_f1_score: 0.9275 - macro_f1_score: 0.9056 - val_loss: 0.9619 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7148
#
# Epoch 00031: val_macro_f1_score did not improve from 0.72783
# Epoch 32/100
# 223/223 [==============================] - 34s 153ms/step - loss: 0.4685 - accuracy: 0.9162 - micro_f1_score: 0.9162 - macro_f1_score: 0.8890 - val_loss: 1.0137 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6843
#
# Epoch 00032: val_macro_f1_score did not improve from 0.72783
# Epoch 33/100
# 223/223 [==============================] - 39s 174ms/step - loss: 0.4577 - accuracy: 0.9264 - micro_f1_score: 0.9264 - macro_f1_score: 0.9080 - val_loss: 1.0285 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6682
#
# Epoch 00033: val_macro_f1_score did not improve from 0.72783
# Epoch 34/100
# 223/223 [==============================] - 38s 169ms/step - loss: 0.4520 - accuracy: 0.9288 - micro_f1_score: 0.9288 - macro_f1_score: 0.9075 - val_loss: 1.0312 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6779
#
# Epoch 00034: val_macro_f1_score did not improve from 0.72783
# Epoch 35/100
# 223/223 [==============================] - 41s 184ms/step - loss: 0.4293 - accuracy: 0.9284 - micro_f1_score: 0.9284 - macro_f1_score: 0.9066 - val_loss: 1.0136 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7115
#
# Epoch 00035: val_macro_f1_score did not improve from 0.72783
# Epoch 36/100
# 223/223 [==============================] - 39s 176ms/step - loss: 0.4240 - accuracy: 0.9320 - micro_f1_score: 0.9320 - macro_f1_score: 0.9141 - val_loss: 1.0769 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6755
#
# Epoch 00036: val_macro_f1_score did not improve from 0.72783
# Epoch 37/100
# 223/223 [==============================] - 39s 175ms/step - loss: 0.3928 - accuracy: 0.9411 - micro_f1_score: 0.9411 - macro_f1_score: 0.9202 - val_loss: 0.9960 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6820
#
# Epoch 00037: val_macro_f1_score did not improve from 0.72783
# Epoch 38/100
# 223/223 [==============================] - 36s 161ms/step - loss: 0.3968 - accuracy: 0.9381 - micro_f1_score: 0.9381 - macro_f1_score: 0.9190 - val_loss: 1.0632 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6552
#
# Epoch 00038: val_macro_f1_score did not improve from 0.72783
# Epoch 39/100
# 223/223 [==============================] - 41s 184ms/step - loss: 0.4160 - accuracy: 0.9346 - micro_f1_score: 0.9346 - macro_f1_score: 0.9137 - val_loss: 1.0537 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6893
#
# Epoch 00039: val_macro_f1_score did not improve from 0.72783
# Epoch 40/100
# 223/223 [==============================] - 40s 179ms/step - loss: 0.4141 - accuracy: 0.9375 - micro_f1_score: 0.9375 - macro_f1_score: 0.9222 - val_loss: 1.0273 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6820
#
# Epoch 00040: val_macro_f1_score did not improve from 0.72783
# Epoch 41/100
# 223/223 [==============================] - 40s 180ms/step - loss: 0.3965 - accuracy: 0.9371 - micro_f1_score: 0.9371 - macro_f1_score: 0.9197 - val_loss: 1.1079 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6816
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00041: val_macro_f1_score did not improve from 0.72783
# Epoch 42/100
# 223/223 [==============================] - 40s 180ms/step - loss: 0.3624 - accuracy: 0.9484 - micro_f1_score: 0.9484 - macro_f1_score: 0.9340 - val_loss: 1.0625 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6982
#
# Epoch 00042: val_macro_f1_score did not improve from 0.72783
# Epoch 43/100
# 223/223 [==============================] - 39s 175ms/step - loss: 0.2895 - accuracy: 0.9674 - micro_f1_score: 0.9674 - macro_f1_score: 0.9597 - val_loss: 1.0540 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.7028
#
# Epoch 00043: val_macro_f1_score did not improve from 0.72783
# Epoch 44/100
# 223/223 [==============================] - 36s 161ms/step - loss: 0.2775 - accuracy: 0.9656 - micro_f1_score: 0.9656 - macro_f1_score: 0.9563 - val_loss: 1.0524 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6989
#
# Epoch 00044: val_macro_f1_score did not improve from 0.72783
# Epoch 45/100
# 223/223 [==============================] - 41s 182ms/step - loss: 0.2441 - accuracy: 0.9734 - micro_f1_score: 0.9734 - macro_f1_score: 0.9658 - val_loss: 1.0528 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6966
#
# Epoch 00045: val_macro_f1_score did not improve from 0.72783
# Epoch 46/100
# 223/223 [==============================] - 39s 177ms/step - loss: 0.2431 - accuracy: 0.9704 - micro_f1_score: 0.9704 - macro_f1_score: 0.9627 - val_loss: 1.0589 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6835
#
# Epoch 00046: val_macro_f1_score did not improve from 0.72783
# Epoch 47/100
# 223/223 [==============================] - 41s 185ms/step - loss: 0.2324 - accuracy: 0.9721 - micro_f1_score: 0.9721 - macro_f1_score: 0.9651 - val_loss: 1.0550 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6938
#
# Epoch 00047: val_macro_f1_score did not improve from 0.72783
# Epoch 48/100
# 223/223 [==============================] - 35s 155ms/step - loss: 0.2273 - accuracy: 0.9710 - micro_f1_score: 0.9710 - macro_f1_score: 0.9639 - val_loss: 1.0542 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6921
#
# Epoch 00048: val_macro_f1_score did not improve from 0.72783
# Epoch 49/100
# 223/223 [==============================] - 33s 149ms/step - loss: 0.2016 - accuracy: 0.9765 - micro_f1_score: 0.9765 - macro_f1_score: 0.9706 - val_loss: 1.0584 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6929
# Epoch 00049: val_macro_f1_score did not improve from 0.72783
# Epoch 50/100
# 223/223 [==============================] - 33s 150ms/step - loss: 0.2028 - accuracy: 0.9757 - micro_f1_score: 0.9757 - macro_f1_score: 0.9701 - val_loss: 1.0470 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6851
#
# Epoch 00050: val_macro_f1_score did not improve from 0.72783
# Epoch 51/100
# 223/223 [==============================] - 40s 178ms/step - loss: 0.2052 - accuracy: 0.9730 - micro_f1_score: 0.9730 - macro_f1_score: 0.9661 - val_loss: 1.0715 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6937
#
# Epoch 00051: val_macro_f1_score did not improve from 0.72783

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_02, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_02, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.7231671847403)

# %% [markdown]
# ##### Plot learning rate of micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_02, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_02, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9933377534151078)

# %% [markdown]
# ##### Predict test data with original model nodes' weight

# %%
#model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model_02.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 41ms/step - loss: 1.0249 - accuracy: 0.7222 - micro_f1_score: 0.7222 - macro_f1_score: 0.6653
# Test Loss: 1.0248937606811523
# Test Accuracy: 0.7222222089767456
# Micro F1-Score: 0.7222221493721008
# Macro F1-Score: 0.6653129458427429

# %% [markdown]
# ##### Load best node weights' from checkpoint and predict on test data

# %%
model_02.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model_02.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 39ms/step - loss: 0.9446 - accuracy: 0.7391 - micro_f1_score: 0.7391 - macro_f1_score: 0.6698
# Test Loss: 0.9445893168449402
# Test Accuracy: 0.7390572428703308
# Micro F1-Score: 0.739057183265686
# Macro F1-Score: 0.6698465943336487

# %% [markdown]
# #### Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.5 <a class="anchor" id="two_bilstm_05"></a>
#
# Different dropout rate is tested.

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model_05 = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network with parameters

# %%
model_05.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### View summary architecture of neural network model

# %%
model_05.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 100, 128)          1571968
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 100, 128)          98816
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,716,355
# Trainable params: 1,716,355
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 40,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 50)

# %% [markdown]
# ##### Train neural network model

# %%
history_05 = model_05.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 51s 170ms/step - loss: 1123.6684 - accuracy: 0.5749 - micro_f1_score: 0.5749 - macro_f1_score: 0.3807 - val_loss: 658.9946 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.5033
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.50330, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 35s 159ms/step - loss: 577.0820 - accuracy: 0.7322 - micro_f1_score: 0.7322 - macro_f1_score: 0.5324 - val_loss: 388.3253 - val_accuracy: 0.6548 - val_micro_f1_score: 0.6548 - val_macro_f1_score: 0.4910
#
# Epoch 00002: val_macro_f1_score did not improve from 0.50330
# Epoch 3/100
# 223/223 [==============================] - 35s 158ms/step - loss: 346.7751 - accuracy: 0.7355 - micro_f1_score: 0.7355 - macro_f1_score: 0.5445 - val_loss: 245.2791 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6061
#
# Epoch 00003: val_macro_f1_score improved from 0.50330 to 0.60605, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 36s 160ms/step - loss: 221.0456 - accuracy: 0.7519 - micro_f1_score: 0.7519 - macro_f1_score: 0.6044 - val_loss: 160.3438 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6128
#
# Epoch 00004: val_macro_f1_score improved from 0.60605 to 0.61281, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 36s 159ms/step - loss: 145.2202 - accuracy: 0.7506 - micro_f1_score: 0.7506 - macro_f1_score: 0.6242 - val_loss: 106.9070 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6010
#
# Epoch 00005: val_macro_f1_score did not improve from 0.61281
# Epoch 6/100
# 223/223 [==============================] - 35s 159ms/step - loss: 97.0956 - accuracy: 0.7614 - micro_f1_score: 0.7614 - macro_f1_score: 0.6419 - val_loss: 72.1539 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6205
#
# Epoch 00006: val_macro_f1_score improved from 0.61281 to 0.62054, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 7/100
# 223/223 [==============================] - 36s 164ms/step - loss: 65.6247 - accuracy: 0.7558 - micro_f1_score: 0.7558 - macro_f1_score: 0.6573 - val_loss: 49.0827 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6037
#
# Epoch 00007: val_macro_f1_score did not improve from 0.62054
# Epoch 8/100
# 223/223 [==============================] - 35s 159ms/step - loss: 44.6375 - accuracy: 0.7628 - micro_f1_score: 0.7628 - macro_f1_score: 0.6636 - val_loss: 33.5389 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6122
#
# Epoch 00008: val_macro_f1_score did not improve from 0.62054
# Epoch 9/100
# 223/223 [==============================] - 35s 157ms/step - loss: 30.4919 - accuracy: 0.7771 - micro_f1_score: 0.7771 - macro_f1_score: 0.6732 - val_loss: 23.0280 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6130
#
# Epoch 00009: val_macro_f1_score did not improve from 0.62054
# Epoch 10/100
# 223/223 [==============================] - 35s 157ms/step - loss: 20.9253 - accuracy: 0.7692 - micro_f1_score: 0.7692 - macro_f1_score: 0.6710 - val_loss: 15.8797 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.6076
#
# Epoch 00010: val_macro_f1_score did not improve from 0.62054
# Epoch 11/100
# 223/223 [==============================] - 37s 167ms/step - loss: 14.3673 - accuracy: 0.7823 - micro_f1_score: 0.7823 - macro_f1_score: 0.6901 - val_loss: 11.0041 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6331
#
# Epoch 00011: val_macro_f1_score improved from 0.62054 to 0.63312, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 12/100
# 223/223 [==============================] - 39s 177ms/step - loss: 9.9321 - accuracy: 0.7825 - micro_f1_score: 0.7825 - macro_f1_score: 0.6903 - val_loss: 7.6717 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6569
#
# Epoch 00012: val_macro_f1_score improved from 0.63312 to 0.65693, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 13/100
# 223/223 [==============================] - 41s 183ms/step - loss: 6.9176 - accuracy: 0.7756 - micro_f1_score: 0.7756 - macro_f1_score: 0.6853 - val_loss: 5.4528 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6320
#
# Epoch 00013: val_macro_f1_score did not improve from 0.65693
# Epoch 14/100
# 223/223 [==============================] - 42s 190ms/step - loss: 4.8802 - accuracy: 0.7802 - micro_f1_score: 0.7802 - macro_f1_score: 0.6981 - val_loss: 3.9027 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6664
#
# Epoch 00014: val_macro_f1_score improved from 0.65693 to 0.66644, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 15/100
# 223/223 [==============================] - 35s 155ms/step - loss: 3.4806 - accuracy: 0.7822 - micro_f1_score: 0.7822 - macro_f1_score: 0.6972 - val_loss: 2.9413 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.6445
#
# Epoch 00015: val_macro_f1_score did not improve from 0.66644
# Epoch 16/100
# 223/223 [==============================] - 34s 152ms/step - loss: 2.5557 - accuracy: 0.7813 - micro_f1_score: 0.7813 - macro_f1_score: 0.7000 - val_loss: 2.2268 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6570
#
# Epoch 00016: val_macro_f1_score did not improve from 0.66644
# Epoch 17/100
# 223/223 [==============================] - 34s 152ms/step - loss: 1.9313 - accuracy: 0.7859 - micro_f1_score: 0.7859 - macro_f1_score: 0.7016 - val_loss: 1.7656 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6597
#
# Epoch 00017: val_macro_f1_score did not improve from 0.66644
# Epoch 18/100
# 223/223 [==============================] - 34s 153ms/step - loss: 1.5089 - accuracy: 0.7935 - micro_f1_score: 0.7935 - macro_f1_score: 0.7211 - val_loss: 1.4698 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6412
#
# Epoch 00018: val_macro_f1_score did not improve from 0.66644
# Epoch 19/100
# 223/223 [==============================] - 34s 151ms/step - loss: 1.2136 - accuracy: 0.8070 - micro_f1_score: 0.8070 - macro_f1_score: 0.7376 - val_loss: 1.2308 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6445
#
# Epoch 00019: val_macro_f1_score did not improve from 0.66644
# Epoch 20/100
# 223/223 [==============================] - 34s 153ms/step - loss: 1.0359 - accuracy: 0.8082 - micro_f1_score: 0.8082 - macro_f1_score: 0.7428 - val_loss: 1.0928 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6679
#
# Epoch 00020: val_macro_f1_score improved from 0.66644 to 0.66789, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 21/100
# 223/223 [==============================] - 35s 156ms/step - loss: 0.9064 - accuracy: 0.8226 - micro_f1_score: 0.8226 - macro_f1_score: 0.7696 - val_loss: 1.0403 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6617
#
# Epoch 00021: val_macro_f1_score did not improve from 0.66789
# Epoch 22/100
# 223/223 [==============================] - 34s 154ms/step - loss: 0.8319 - accuracy: 0.8224 - micro_f1_score: 0.8224 - macro_f1_score: 0.7672 - val_loss: 0.9877 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6793
#
# Epoch 00022: val_macro_f1_score improved from 0.66789 to 0.67933, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 23/100
# 223/223 [==============================] - 35s 155ms/step - loss: 0.6969 - accuracy: 0.8519 - micro_f1_score: 0.8519 - macro_f1_score: 0.8019 - val_loss: 0.9112 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7195
#
# Epoch 00023: val_macro_f1_score improved from 0.67933 to 0.71946, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 24/100
# 223/223 [==============================] - 34s 154ms/step - loss: 0.6687 - accuracy: 0.8557 - micro_f1_score: 0.8557 - macro_f1_score: 0.8120 - val_loss: 0.8898 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7040
# Epoch 00024: val_macro_f1_score did not improve from 0.71946
# Epoch 25/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.6234 - accuracy: 0.8631 - micro_f1_score: 0.8631 - macro_f1_score: 0.8197 - val_loss: 0.8857 - val_accuracy: 0.7563 - val_micro_f1_score: 0.7563 - val_macro_f1_score: 0.7116
#
# Epoch 00025: val_macro_f1_score did not improve from 0.71946
# Epoch 26/100
# 223/223 [==============================] - 35s 157ms/step - loss: 0.5594 - accuracy: 0.8869 - micro_f1_score: 0.8869 - macro_f1_score: 0.8490 - val_loss: 0.9131 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6737
#
# Epoch 00026: val_macro_f1_score did not improve from 0.71946
# Epoch 27/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.5351 - accuracy: 0.8906 - micro_f1_score: 0.8906 - macro_f1_score: 0.8527 - val_loss: 0.9541 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.7006
#
# Epoch 00027: val_macro_f1_score did not improve from 0.71946
# Epoch 28/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.5177 - accuracy: 0.9021 - micro_f1_score: 0.9021 - macro_f1_score: 0.8722 - val_loss: 0.9440 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6836
#
# Epoch 00028: val_macro_f1_score did not improve from 0.71946
# Epoch 29/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.5220 - accuracy: 0.8953 - micro_f1_score: 0.8953 - macro_f1_score: 0.8641 - val_loss: 0.9344 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6753
#
# Epoch 00029: val_macro_f1_score did not improve from 0.71946
# Epoch 30/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4918 - accuracy: 0.9091 - micro_f1_score: 0.9091 - macro_f1_score: 0.8808 - val_loss: 0.9477 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6663
#
# Epoch 00030: val_macro_f1_score did not improve from 0.71946
# Epoch 31/100
# 223/223 [==============================] - 34s 153ms/step - loss: 0.4607 - accuracy: 0.9191 - micro_f1_score: 0.9191 - macro_f1_score: 0.8938 - val_loss: 0.9542 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6892
#
# Epoch 00031: val_macro_f1_score did not improve from 0.71946
# Epoch 32/100
# 223/223 [==============================] - 34s 153ms/step - loss: 0.4792 - accuracy: 0.9075 - micro_f1_score: 0.9075 - macro_f1_score: 0.8798 - val_loss: 0.9662 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6963
#
# Epoch 00032: val_macro_f1_score did not improve from 0.71946
# Epoch 33/100
# 223/223 [==============================] - 35s 155ms/step - loss: 0.4460 - accuracy: 0.9223 - micro_f1_score: 0.9223 - macro_f1_score: 0.8981 - val_loss: 0.9567 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6829
#
# Epoch 00033: val_macro_f1_score did not improve from 0.71946
# Epoch 34/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4299 - accuracy: 0.9310 - micro_f1_score: 0.9310 - macro_f1_score: 0.9111 - val_loss: 0.9848 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7244
#
# Epoch 00034: val_macro_f1_score improved from 0.71946 to 0.72440, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 35/100
# 223/223 [==============================] - 34s 153ms/step - loss: 0.4551 - accuracy: 0.9241 - micro_f1_score: 0.9241 - macro_f1_score: 0.9026 - val_loss: 0.9799 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6784
#
# Epoch 00035: val_macro_f1_score did not improve from 0.72440
# Epoch 36/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4153 - accuracy: 0.9346 - micro_f1_score: 0.9346 - macro_f1_score: 0.9146 - val_loss: 0.9917 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6908
#
# Epoch 00036: val_macro_f1_score did not improve from 0.72440
# Epoch 37/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.4226 - accuracy: 0.9281 - micro_f1_score: 0.9281 - macro_f1_score: 0.9057 - val_loss: 0.9748 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6664
#
# Epoch 00037: val_macro_f1_score did not improve from 0.72440
# Epoch 38/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4189 - accuracy: 0.9268 - micro_f1_score: 0.9268 - macro_f1_score: 0.9006 - val_loss: 0.9842 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6644
#
# Epoch 00038: val_macro_f1_score did not improve from 0.72440
# Epoch 39/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4083 - accuracy: 0.9308 - micro_f1_score: 0.9308 - macro_f1_score: 0.9120 - val_loss: 1.0862 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6325
#
# Epoch 00039: val_macro_f1_score did not improve from 0.72440
# Epoch 40/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.4038 - accuracy: 0.9340 - micro_f1_score: 0.9340 - macro_f1_score: 0.9136 - val_loss: 0.9602 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6760
#
# Epoch 00040: val_macro_f1_score did not improve from 0.72440
# Epoch 41/100
# 223/223 [==============================] - 33s 150ms/step - loss: 0.3741 - accuracy: 0.9390 - micro_f1_score: 0.9390 - macro_f1_score: 0.9191 - val_loss: 1.0023 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6979
#
# Epoch 00041: val_macro_f1_score did not improve from 0.72440
# Epoch 42/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.3751 - accuracy: 0.9407 - micro_f1_score: 0.9407 - macro_f1_score: 0.9227 - val_loss: 1.0543 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6456
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00042: val_macro_f1_score did not improve from 0.72440
# Epoch 43/100
# 223/223 [==============================] - 34s 154ms/step - loss: 0.3414 - accuracy: 0.9544 - micro_f1_score: 0.9544 - macro_f1_score: 0.9414 - val_loss: 1.0433 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6716
#
# Epoch 00043: val_macro_f1_score did not improve from 0.72440
# Epoch 44/100
# 223/223 [==============================] - 36s 161ms/step - loss: 0.2692 - accuracy: 0.9691 - micro_f1_score: 0.9691 - macro_f1_score: 0.9599 - val_loss: 1.0524 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6679
#
# Epoch 00044: val_macro_f1_score did not improve from 0.72440
# Epoch 45/100
# 223/223 [==============================] - 34s 154ms/step - loss: 0.2495 - accuracy: 0.9724 - micro_f1_score: 0.9724 - macro_f1_score: 0.9650 - val_loss: 1.0535 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6858
#
# Epoch 00045: val_macro_f1_score did not improve from 0.72440
# Epoch 46/100
# 223/223 [==============================] - 35s 155ms/step - loss: 0.2418 - accuracy: 0.9724 - micro_f1_score: 0.9724 - macro_f1_score: 0.9654 - val_loss: 1.0856 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6682
#
# Epoch 00046: val_macro_f1_score did not improve from 0.72440
# Epoch 47/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.2211 - accuracy: 0.9755 - micro_f1_score: 0.9755 - macro_f1_score: 0.9688 - val_loss: 1.0920 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6682
#
# Epoch 00047: val_macro_f1_score did not improve from 0.72440
# Epoch 48/100
# 223/223 [==============================] - 34s 151ms/step - loss: 0.2313 - accuracy: 0.9718 - micro_f1_score: 0.9718 - macro_f1_score: 0.9647 - val_loss: 1.0831 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6644
#
# Epoch 00048: val_macro_f1_score did not improve from 0.72440
# Epoch 49/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.2136 - accuracy: 0.9758 - micro_f1_score: 0.9758 - macro_f1_score: 0.9702 - val_loss: 1.0887 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6693
#
# Epoch 00049: val_macro_f1_score did not improve from 0.72440
# Epoch 50/100
# 223/223 [==============================] - 34s 152ms/step - loss: 0.2098 - accuracy: 0.9739 - micro_f1_score: 0.9739 - macro_f1_score: 0.9676 - val_loss: 1.0849 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6725
#
# Epoch 00050: val_macro_f1_score did not improve from 0.72440
# Epoch 51/100
# 223/223 [==============================] - 36s 163ms/step - loss: 0.2120 - accuracy: 0.9719 - micro_f1_score: 0.9719 - macro_f1_score: 0.9647 - val_loss: 1.0951 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6812
#
# Epoch 00051: val_macro_f1_score did not improve from 0.72440
# Epoch 52/100
# 223/223 [==============================] - 32s 142ms/step - loss: 0.1923 - accuracy: 0.9764 - micro_f1_score: 0.9764 - macro_f1_score: 0.9700 - val_loss: 1.1132 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6726
#
# Epoch 00052: val_macro_f1_score did not improve from 0.72440

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_05, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_05, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.7415519461035)

# %% [markdown]
# ##### Plot learning rate for micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_05, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_05, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9940688982605934)

# %% [markdown]
# ##### Load best weights on each node and predict on test data.
#
# accuracy: 73.51%
#
#
# I accidently changed the type of cell to markdown and the output is gone 😭

# %%
model_05.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model_05.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)

# %% [markdown]
# #### Two Layer Bidirectional Long-Short Term Memory (biLSTM) + dropout 0.7 <a class="anchor" id="two_bilstm_07"></a>

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model_07 = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dropout(0.7),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network model with parameters

# %%
model_07.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 40,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 50)

# %% [markdown]
# ##### Train neural network model

# %%
history_07 = model_07.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 60s 204ms/step - loss: 1123.6743 - accuracy: 0.5872 - micro_f1_score: 0.5872 - macro_f1_score: 0.4132 - val_loss: 658.9956 - val_accuracy: 0.6599 - val_micro_f1_score: 0.6599 - val_macro_f1_score: 0.4983
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.49831, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 42s 191ms/step - loss: 577.0913 - accuracy: 0.7231 - micro_f1_score: 0.7231 - macro_f1_score: 0.5266 - val_loss: 388.3137 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.5201
#
# Epoch 00002: val_macro_f1_score improved from 0.49831 to 0.52006, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 38s 171ms/step - loss: 346.7947 - accuracy: 0.7239 - micro_f1_score: 0.7239 - macro_f1_score: 0.5292 - val_loss: 245.2698 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5260
#
# Epoch 00003: val_macro_f1_score improved from 0.52006 to 0.52601, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 42s 188ms/step - loss: 221.0416 - accuracy: 0.7493 - micro_f1_score: 0.7493 - macro_f1_score: 0.5461 - val_loss: 160.3520 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.5221
#
# Epoch 00004: val_macro_f1_score did not improve from 0.52601
# Epoch 5/100
# 223/223 [==============================] - 40s 180ms/step - loss: 145.2262 - accuracy: 0.7379 - micro_f1_score: 0.7379 - macro_f1_score: 0.5374 - val_loss: 106.9256 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.5041
#
# Epoch 00005: val_macro_f1_score did not improve from 0.52601
# Epoch 6/100
# 223/223 [==============================] - 40s 181ms/step - loss: 97.0913 - accuracy: 0.7403 - micro_f1_score: 0.7403 - macro_f1_score: 0.5659 - val_loss: 72.1467 - val_accuracy: 0.6802 - val_micro_f1_score: 0.6802 - val_macro_f1_score: 0.5166
#
# Epoch 00006: val_macro_f1_score did not improve from 0.52601
# Epoch 7/100
# 223/223 [==============================] - 38s 173ms/step - loss: 65.6295 - accuracy: 0.7411 - micro_f1_score: 0.7411 - macro_f1_score: 0.5729 - val_loss: 49.0683 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5453
#
# Epoch 00007: val_macro_f1_score improved from 0.52601 to 0.54530, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 8/100
# 223/223 [==============================] - 37s 164ms/step - loss: 44.6370 - accuracy: 0.7492 - micro_f1_score: 0.7492 - macro_f1_score: 0.6147 - val_loss: 33.5795 - val_accuracy: 0.6853 - val_micro_f1_score: 0.6853 - val_macro_f1_score: 0.6079
#
# Epoch 00008: val_macro_f1_score improved from 0.54530 to 0.60793, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 9/100
# 223/223 [==============================] - 43s 192ms/step - loss: 30.5241 - accuracy: 0.7439 - micro_f1_score: 0.7439 - macro_f1_score: 0.6121 - val_loss: 23.0719 - val_accuracy: 0.6650 - val_micro_f1_score: 0.6650 - val_macro_f1_score: 0.5618
#
# Epoch 00009: val_macro_f1_score did not improve from 0.60793
# Epoch 10/100
# 223/223 [==============================] - 39s 174ms/step - loss: 20.9189 - accuracy: 0.7535 - micro_f1_score: 0.7535 - macro_f1_score: 0.6321 - val_loss: 15.8729 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6168
#
# Epoch 00010: val_macro_f1_score improved from 0.60793 to 0.61680, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 11/100
# 223/223 [==============================] - 42s 186ms/step - loss: 14.3716 - accuracy: 0.7664 - micro_f1_score: 0.7664 - macro_f1_score: 0.6496 - val_loss: 11.0739 - val_accuracy: 0.6548 - val_micro_f1_score: 0.6548 - val_macro_f1_score: 0.5643
#
# Epoch 00011: val_macro_f1_score did not improve from 0.61680
# Epoch 12/100
# 223/223 [==============================] - 40s 181ms/step - loss: 9.9581 - accuracy: 0.7546 - micro_f1_score: 0.7546 - macro_f1_score: 0.6469 - val_loss: 7.6830 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5813
#
# Epoch 00012: val_macro_f1_score did not improve from 0.61680
# Epoch 13/100
# 223/223 [==============================] - 39s 177ms/step - loss: 6.9300 - accuracy: 0.7571 - micro_f1_score: 0.7571 - macro_f1_score: 0.6436 - val_loss: 5.4569 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6267
#
# Epoch 00013: val_macro_f1_score improved from 0.61680 to 0.62674, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 14/100
# 223/223 [==============================] - 42s 189ms/step - loss: 4.8829 - accuracy: 0.7596 - micro_f1_score: 0.7596 - macro_f1_score: 0.6469 - val_loss: 3.9370 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5758
#
# Epoch 00014: val_macro_f1_score did not improve from 0.62674
# Epoch 15/100
# 223/223 [==============================] - 39s 175ms/step - loss: 3.4995 - accuracy: 0.7599 - micro_f1_score: 0.7599 - macro_f1_score: 0.6422 - val_loss: 2.9225 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6130
#
# Epoch 00015: val_macro_f1_score did not improve from 0.62674
# Epoch 16/100
# 223/223 [==============================] - 43s 192ms/step - loss: 2.5941 - accuracy: 0.7644 - micro_f1_score: 0.7644 - macro_f1_score: 0.6596 - val_loss: 2.2111 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5987
#
# Epoch 00016: val_macro_f1_score did not improve from 0.62674
# Epoch 17/100
# 223/223 [==============================] - 41s 185ms/step - loss: 1.9180 - accuracy: 0.7860 - micro_f1_score: 0.7860 - macro_f1_score: 0.6897 - val_loss: 1.7965 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6548
#
# Epoch 00017: val_macro_f1_score improved from 0.62674 to 0.65484, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 18/100
# 223/223 [==============================] - 41s 184ms/step - loss: 1.5456 - accuracy: 0.7803 - micro_f1_score: 0.7803 - macro_f1_score: 0.6936 - val_loss: 1.4854 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6574
#
# Epoch 00018: val_macro_f1_score improved from 0.65484 to 0.65743, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 19/100
# 223/223 [==============================] - 40s 180ms/step - loss: 1.2384 - accuracy: 0.7923 - micro_f1_score: 0.7923 - macro_f1_score: 0.6939 - val_loss: 1.2791 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5864
#
# Epoch 00019: val_macro_f1_score did not improve from 0.65743
# Epoch 20/100
# 223/223 [==============================] - 41s 182ms/step - loss: 1.0596 - accuracy: 0.7980 - micro_f1_score: 0.7980 - macro_f1_score: 0.7255 - val_loss: 1.1834 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5831
#
# Epoch 00020: val_macro_f1_score did not improve from 0.65743
# Epoch 21/100
# 223/223 [==============================] - 41s 184ms/step - loss: 0.9274 - accuracy: 0.8027 - micro_f1_score: 0.8027 - macro_f1_score: 0.7264 - val_loss: 1.0576 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6788
#
# Epoch 00021: val_macro_f1_score improved from 0.65743 to 0.67879, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 22/100
# 223/223 [==============================] - 42s 186ms/step - loss: 0.8468 - accuracy: 0.8081 - micro_f1_score: 0.8081 - macro_f1_score: 0.7442 - val_loss: 0.9478 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6968
#
# Epoch 00022: val_macro_f1_score improved from 0.67879 to 0.69678, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 23/100
# 223/223 [==============================] - 44s 197ms/step - loss: 0.7513 - accuracy: 0.8268 - micro_f1_score: 0.8268 - macro_f1_score: 0.7727 - val_loss: 0.9555 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.6812
#
# Epoch 00023: val_macro_f1_score did not improve from 0.69678
# Epoch 24/100
# 223/223 [==============================] - 37s 164ms/step - loss: 0.7179 - accuracy: 0.8314 - micro_f1_score: 0.8314 - macro_f1_score: 0.7761 - val_loss: 0.9428 - val_accuracy: 0.7107 - val_micro_f1_score: 0.7107 - val_macro_f1_score: 0.6740
# Epoch 00024: val_macro_f1_score did not improve from 0.69678
# Epoch 25/100
# 223/223 [==============================] - 34s 154ms/step - loss: 0.6468 - accuracy: 0.8555 - micro_f1_score: 0.8555 - macro_f1_score: 0.8048 - val_loss: 0.9079 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.7000
#
# Epoch 00025: val_macro_f1_score improved from 0.69678 to 0.69998, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 26/100
# 223/223 [==============================] - 35s 158ms/step - loss: 0.6308 - accuracy: 0.8628 - micro_f1_score: 0.8628 - macro_f1_score: 0.8188 - val_loss: 0.8872 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7263
#
# Epoch 00026: val_macro_f1_score improved from 0.69998 to 0.72635, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 27/100
# 223/223 [==============================] - 36s 160ms/step - loss: 0.5843 - accuracy: 0.8782 - micro_f1_score: 0.8782 - macro_f1_score: 0.8355 - val_loss: 0.8564 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.6976
#
# Epoch 00027: val_macro_f1_score did not improve from 0.72635
# Epoch 28/100
# 223/223 [==============================] - 36s 163ms/step - loss: 0.5521 - accuracy: 0.8902 - micro_f1_score: 0.8902 - macro_f1_score: 0.8502 - val_loss: 0.8339 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7247
#
# Epoch 00028: val_macro_f1_score did not improve from 0.72635
# Epoch 29/100
# 223/223 [==============================] - 32s 145ms/step - loss: 0.5714 - accuracy: 0.8748 - micro_f1_score: 0.8748 - macro_f1_score: 0.8331 - val_loss: 0.8807 - val_accuracy: 0.7716 - val_micro_f1_score: 0.7716 - val_macro_f1_score: 0.7454
#
# Epoch 00029: val_macro_f1_score improved from 0.72635 to 0.74541, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 30/100
# 223/223 [==============================] - 31s 140ms/step - loss: 0.5501 - accuracy: 0.8876 - micro_f1_score: 0.8876 - macro_f1_score: 0.8508 - val_loss: 0.8199 - val_accuracy: 0.7563 - val_micro_f1_score: 0.7563 - val_macro_f1_score: 0.7186
#
# Epoch 00030: val_macro_f1_score did not improve from 0.74541
# Epoch 31/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.5421 - accuracy: 0.8895 - micro_f1_score: 0.8895 - macro_f1_score: 0.8566 - val_loss: 0.9195 - val_accuracy: 0.7259 - val_micro_f1_score: 0.7259 - val_macro_f1_score: 0.6871
#
# Epoch 00031: val_macro_f1_score did not improve from 0.74541
# Epoch 32/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.5115 - accuracy: 0.8987 - micro_f1_score: 0.8987 - macro_f1_score: 0.8645 - val_loss: 0.8923 - val_accuracy: 0.7665 - val_micro_f1_score: 0.7665 - val_macro_f1_score: 0.7356
#
# Epoch 00032: val_macro_f1_score did not improve from 0.74541
# Epoch 33/100
# 223/223 [==============================] - 31s 137ms/step - loss: 0.5274 - accuracy: 0.8954 - micro_f1_score: 0.8954 - macro_f1_score: 0.8592 - val_loss: 0.9697 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.7005
#
# Epoch 00033: val_macro_f1_score did not improve from 0.74541
# Epoch 34/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.5061 - accuracy: 0.9080 - micro_f1_score: 0.9080 - macro_f1_score: 0.8786 - val_loss: 0.9435 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6933
#
# Epoch 00034: val_macro_f1_score did not improve from 0.74541
# Epoch 35/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.5069 - accuracy: 0.9028 - micro_f1_score: 0.9028 - macro_f1_score: 0.8723 - val_loss: 0.9519 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.6970
#
# Epoch 00035: val_macro_f1_score did not improve from 0.74541
# Epoch 36/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.4864 - accuracy: 0.9114 - micro_f1_score: 0.9114 - macro_f1_score: 0.8822 - val_loss: 0.9670 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6807
#
# Epoch 00036: val_macro_f1_score did not improve from 0.74541
# Epoch 37/100
# 223/223 [==============================] - 31s 139ms/step - loss: 0.4930 - accuracy: 0.9080 - micro_f1_score: 0.9080 - macro_f1_score: 0.8796 - val_loss: 0.9319 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6980
#
# Epoch 00037: val_macro_f1_score did not improve from 0.74541
# Epoch 38/100
# 223/223 [==============================] - 31s 139ms/step - loss: 0.4723 - accuracy: 0.9133 - micro_f1_score: 0.9133 - macro_f1_score: 0.8831 - val_loss: 1.0118 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6966
#
# Epoch 00038: val_macro_f1_score did not improve from 0.74541
# Epoch 39/100
# 223/223 [==============================] - 31s 137ms/step - loss: 0.4736 - accuracy: 0.9120 - micro_f1_score: 0.9120 - macro_f1_score: 0.8834 - val_loss: 0.9481 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7170
#
# Epoch 00039: val_macro_f1_score did not improve from 0.74541
# Epoch 40/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.4448 - accuracy: 0.9244 - micro_f1_score: 0.9244 - macro_f1_score: 0.8980 - val_loss: 0.9896 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6718
#
# Epoch 00040: val_macro_f1_score did not improve from 0.74541
# Epoch 41/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.4398 - accuracy: 0.9208 - micro_f1_score: 0.9208 - macro_f1_score: 0.8950 - val_loss: 0.9294 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7116
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00041: val_macro_f1_score did not improve from 0.74541
# Epoch 42/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.4449 - accuracy: 0.9286 - micro_f1_score: 0.9286 - macro_f1_score: 0.9082 - val_loss: 0.9077 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.7111
#
# Epoch 00042: val_macro_f1_score did not improve from 0.74541
# Epoch 43/100
# 223/223 [==============================] - 31s 137ms/step - loss: 0.3592 - accuracy: 0.9519 - micro_f1_score: 0.9519 - macro_f1_score: 0.9369 - val_loss: 0.9018 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.7068
#
# Epoch 00043: val_macro_f1_score did not improve from 0.74541
# Epoch 44/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.3414 - accuracy: 0.9526 - micro_f1_score: 0.9526 - macro_f1_score: 0.9378 - val_loss: 0.8973 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7209
#
# Epoch 00044: val_macro_f1_score did not improve from 0.74541
# Epoch 45/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.3225 - accuracy: 0.9550 - micro_f1_score: 0.9550 - macro_f1_score: 0.9420 - val_loss: 0.8963 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7231
#
# Epoch 00045: val_macro_f1_score did not improve from 0.74541
# Epoch 46/100
# 223/223 [==============================] - 31s 138ms/step - loss: 0.2937 - accuracy: 0.9617 - micro_f1_score: 0.9617 - macro_f1_score: 0.9505 - val_loss: 0.8994 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7158
#
# Epoch 00046: val_macro_f1_score did not improve from 0.74541
# Epoch 47/100
# 223/223 [==============================] - 31s 140ms/step - loss: 0.2837 - accuracy: 0.9623 - micro_f1_score: 0.9623 - macro_f1_score: 0.9511 - val_loss: 0.9061 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7183
#
# Epoch 00047: val_macro_f1_score did not improve from 0.74541
# Epoch 48/100
# 223/223 [==============================] - 32s 144ms/step - loss: 0.2750 - accuracy: 0.9622 - micro_f1_score: 0.9622 - macro_f1_score: 0.9528 - val_loss: 0.9169 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7198
#
# Epoch 00048: val_macro_f1_score did not improve from 0.74541
# Epoch 49/100
# 223/223 [==============================] - 29s 132ms/step - loss: 0.2771 - accuracy: 0.9587 - micro_f1_score: 0.9587 - macro_f1_score: 0.9485 - val_loss: 0.9179 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.7082
# Epoch 00049: val_macro_f1_score did not improve from 0.74541
# Epoch 50/100
# 223/223 [==============================] - 29s 132ms/step - loss: 0.2560 - accuracy: 0.9628 - micro_f1_score: 0.9628 - macro_f1_score: 0.9521 - val_loss: 0.9087 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7170
#
# Epoch 00050: val_macro_f1_score did not improve from 0.74541
# Epoch 51/100
# 223/223 [==============================] - 30s 133ms/step - loss: 0.2583 - accuracy: 0.9615 - micro_f1_score: 0.9615 - macro_f1_score: 0.9509 - val_loss: 0.8950 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7163
#
# Epoch 00051: val_macro_f1_score did not improve from 0.74541

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_07, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_07, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.7408067256213)

# %% [markdown]
# ##### Plot learning rate of micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history_07, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history_07, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9760373920202255)

# %% [markdown]
# ##### Predict test data on original weights

# %%
#model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model_07.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 32ms/step - loss: 1.0236 - accuracy: 0.7189 - micro_f1_score: 0.7189 - macro_f1_score: 0.6570
# Test Loss: 1.0236423015594482
# Test Accuracy: 0.7188552021980286
# Micro F1-Score: 0.7188551425933838
# Macro F1-Score: 0.6569922566413879

# %% [markdown]
# ##### Load best weights for each nodes and predict on test data
#
# *the accuracy score has dropped*

# %%
model_07.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model_07.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 33ms/step - loss: 0.9098 - accuracy: 0.7290 - micro_f1_score: 0.7290 - macro_f1_score: 0.6626
# Test Loss: 0.9098053574562073
# Test Accuracy: 0.7289562225341797
# Micro F1-Score: 0.7289562821388245
# Macro F1-Score: 0.662600576877594

# %%
def compare_plot_graphs(history_02, history_05, history_07, metric):
    plt.plot(history_02.history[metric])
    plt.plot(history_05.history[metric])
    plt.plot(history_07.history[metric])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# #### Dropout Comparison <a class="anchor" id="dropout_compare"></a>
#
# Plot learning rate of model with dropout rate 0.2, 0.5 and 0.7 to compare their performance

# %% [markdown]
# ##### Plot learning rate of macro F1-score, we can observe that dropout rate with 0.2 have highest learning rate curve, which means that it learned the most among all.
#
# |Dropout | Test Accuracy | Macro F1  |	Test Loss |	Total Epochs |
# | :---   |    :----:     |    :----: |    :----:  |         ---: |
# |0.2	 | 73.91%        |	66.98%   | 0.9446     | 30           |
# |0.5	 | 73.57%        |	68.02%   | 0.9511	  | 34           |
# |0.7	 | 72.90%        |	66.26%   | 0.9098	  | 25           |

# %%
compare_plot_graphs(history_02, history_05, history_07, 'macro_f1_score')
plt.xlabel("Epochs")
plt.ylabel('macro f1-score')
plt.legend(['0.2', '0.5', '0.7'])

# %% [markdown]
# #### Proposed Method <a class="anchor" id="proposed"></a>
#
#
# Batch normalization is introduced to normalize inputs of each neural network layer, thus speed up the neural network training time [(Garbin & Zhu, 2020)](https://link.springer.com/article/10.1007/s11042-019-08453-9). Besides that, batch normalization is also able to increase model’s prediction ability by adjust stochastic value of units each batch and results in noises that act as regularizer. The noises are acted as regularizer in neural network. Hence, by using batch normalization in neural network, dropout layer or L2 regularizer should be removed or have lower rate or else it will be too much noises for the model [(Garbin & Zhu, 2020)](https://link.springer.com/article/10.1007/s11042-019-08453-9).

# %% [markdown]
# ##### Build neural network model

# %%
REGULARIZER = tf.keras.regularizers.L2(0.01)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        input_dim=len(tokenizer.word_index) + 1,
        output_dim=128,
        input_length=100,
        weights=[embedding_matrix],
        embeddings_regularizer=REGULARIZER),
        #embeddings_regularizer = tf.keras.regularizers.L2(0.01),
        # Use masking to handle the variable sequence lengths
        #mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='softmax'),
    tf.keras.layers.Dense(3)
])

# %% [markdown]
# ##### Compile neural network model

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['accuracy',
                        tfa.metrics.F1Score(num_classes= 3, name = 'micro_f1_score', average='micro'),
                        tfa.metrics.F1Score(num_classes= 3, name = 'macro_f1_score', average='macro')])

# %% [markdown]
# ##### View neural network model architecture summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 128)          1571968
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 100, 128)          98816
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,716,611
# Trainable params: 1,716,483
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# ##### Define checkpoint and early stopping

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor= 'val_macro_f1_score',
                                                 factor= 0.1,
                                                 patience= 20,
                                                 verbose= 1,
                                                 min_lr= 0.00001)

#file_path = "cnn_weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint_path = "training_1/w2v_one_layer_lstm_no_emoji.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
#model_chkpt = callbacks.ModelCheckpoint(filepath=file_path,monitor= metric, save_best_only=True)
model_chkpt = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
                                                 monitor='val_macro_f1_score', 
                                                 save_weights_only=True,
                                                 verbose=1, save_best_only=True, mode='max')
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_macro_f1_score', patience = 30)

# %% [markdown]
# ##### Train neural network

# %%
history = model.fit(traintitle, y_train, epochs=100,
                    validation_data=(valtitle, y_val),
                    shuffle=True,
                    batch_size=32,
                    callbacks = [early_stopping_callback, reduce_lr, model_chkpt])
# Out:
# Epoch 1/100
# 223/223 [==============================] - 53s 190ms/step - loss: 1123.6490 - accuracy: 0.7027 - micro_f1_score: 0.7027 - macro_f1_score: 0.5137 - val_loss: 658.9866 - val_accuracy: 0.6497 - val_micro_f1_score: 0.6497 - val_macro_f1_score: 0.4933
#
# Epoch 00001: val_macro_f1_score improved from -inf to 0.49329, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 2/100
# 223/223 [==============================] - 39s 175ms/step - loss: 577.0476 - accuracy: 0.7388 - micro_f1_score: 0.7388 - macro_f1_score: 0.5382 - val_loss: 388.2614 - val_accuracy: 0.6904 - val_micro_f1_score: 0.6904 - val_macro_f1_score: 0.5255
#
# Epoch 00002: val_macro_f1_score improved from 0.49329 to 0.52546, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 3/100
# 223/223 [==============================] - 39s 175ms/step - loss: 346.7311 - accuracy: 0.7491 - micro_f1_score: 0.7491 - macro_f1_score: 0.5984 - val_loss: 245.2633 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5827
#
# Epoch 00003: val_macro_f1_score improved from 0.52546 to 0.58271, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 4/100
# 223/223 [==============================] - 48s 213ms/step - loss: 221.0006 - accuracy: 0.7555 - micro_f1_score: 0.7555 - macro_f1_score: 0.6165 - val_loss: 160.3372 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5875
#
# Epoch 00004: val_macro_f1_score improved from 0.58271 to 0.58749, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 5/100
# 223/223 [==============================] - 54s 243ms/step - loss: 145.1837 - accuracy: 0.7670 - micro_f1_score: 0.7670 - macro_f1_score: 0.6759 - val_loss: 106.8749 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.5887
#
# Epoch 00005: val_macro_f1_score improved from 0.58749 to 0.58865, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 6/100
# 223/223 [==============================] - 51s 229ms/step - loss: 97.0399 - accuracy: 0.7737 - micro_f1_score: 0.7737 - macro_f1_score: 0.6604 - val_loss: 72.1401 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.5907
#
# Epoch 00006: val_macro_f1_score improved from 0.58865 to 0.59071, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 7/100
# 223/223 [==============================] - 46s 204ms/step - loss: 65.5759 - accuracy: 0.7701 - micro_f1_score: 0.7701 - macro_f1_score: 0.6692 - val_loss: 49.0449 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6656
#
# Epoch 00007: val_macro_f1_score improved from 0.59071 to 0.66563, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 8/100
# 223/223 [==============================] - 48s 216ms/step - loss: 44.5959 - accuracy: 0.7830 - micro_f1_score: 0.7830 - macro_f1_score: 0.6912 - val_loss: 33.5603 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5848
#
# Epoch 00008: val_macro_f1_score did not improve from 0.66563
# Epoch 9/100
# 223/223 [==============================] - 49s 220ms/step - loss: 30.4812 - accuracy: 0.7847 - micro_f1_score: 0.7847 - macro_f1_score: 0.6975 - val_loss: 23.0479 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5888
#
# Epoch 00009: val_macro_f1_score did not improve from 0.66563
# Epoch 10/100
# 223/223 [==============================] - 48s 216ms/step - loss: 20.8943 - accuracy: 0.7780 - micro_f1_score: 0.7780 - macro_f1_score: 0.6750 - val_loss: 15.8441 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6029
#
# Epoch 00010: val_macro_f1_score did not improve from 0.66563
# Epoch 11/100
# 223/223 [==============================] - 48s 214ms/step - loss: 14.3609 - accuracy: 0.7947 - micro_f1_score: 0.7947 - macro_f1_score: 0.7206 - val_loss: 11.0269 - val_accuracy: 0.7208 - val_micro_f1_score: 0.7208 - val_macro_f1_score: 0.6517
#
# Epoch 00011: val_macro_f1_score did not improve from 0.66563
# Epoch 12/100
# 223/223 [==============================] - 49s 219ms/step - loss: 9.9444 - accuracy: 0.7860 - micro_f1_score: 0.7860 - macro_f1_score: 0.7038 - val_loss: 7.6937 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5879
#
# Epoch 00012: val_macro_f1_score did not improve from 0.66563
# Epoch 13/100
# 223/223 [==============================] - 47s 212ms/step - loss: 6.9098 - accuracy: 0.7954 - micro_f1_score: 0.7954 - macro_f1_score: 0.7120 - val_loss: 5.5084 - val_accuracy: 0.6751 - val_micro_f1_score: 0.6751 - val_macro_f1_score: 0.6219
#
# Epoch 00013: val_macro_f1_score did not improve from 0.66563
# Epoch 14/100
# 223/223 [==============================] - 47s 212ms/step - loss: 4.8871 - accuracy: 0.7813 - micro_f1_score: 0.7813 - macro_f1_score: 0.7034 - val_loss: 4.0080 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.5821
#
# Epoch 00014: val_macro_f1_score did not improve from 0.66563
# Epoch 15/100
# 223/223 [==============================] - 47s 212ms/step - loss: 3.4894 - accuracy: 0.7927 - micro_f1_score: 0.7927 - macro_f1_score: 0.7015 - val_loss: 2.9379 - val_accuracy: 0.7310 - val_micro_f1_score: 0.7310 - val_macro_f1_score: 0.6515
#
# Epoch 00015: val_macro_f1_score did not improve from 0.66563
# Epoch 16/100
# 223/223 [==============================] - 48s 215ms/step - loss: 2.5854 - accuracy: 0.7896 - micro_f1_score: 0.7896 - macro_f1_score: 0.7131 - val_loss: 2.2828 - val_accuracy: 0.7005 - val_micro_f1_score: 0.7005 - val_macro_f1_score: 0.6212
#
# Epoch 00016: val_macro_f1_score did not improve from 0.66563
# Epoch 17/100
# 223/223 [==============================] - 49s 219ms/step - loss: 1.9499 - accuracy: 0.8024 - micro_f1_score: 0.8024 - macro_f1_score: 0.7329 - val_loss: 1.7858 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.6584
#
# Epoch 00017: val_macro_f1_score did not improve from 0.66563
# Epoch 18/100
# 223/223 [==============================] - 47s 211ms/step - loss: 1.5239 - accuracy: 0.8090 - micro_f1_score: 0.8090 - macro_f1_score: 0.7484 - val_loss: 1.5244 - val_accuracy: 0.7411 - val_micro_f1_score: 0.7411 - val_macro_f1_score: 0.7017
#
# Epoch 00018: val_macro_f1_score improved from 0.66563 to 0.70170, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 19/100
# 223/223 [==============================] - 47s 211ms/step - loss: 1.2616 - accuracy: 0.8073 - micro_f1_score: 0.8073 - macro_f1_score: 0.7416 - val_loss: 1.3500 - val_accuracy: 0.6954 - val_micro_f1_score: 0.6954 - val_macro_f1_score: 0.5976
#
# Epoch 00019: val_macro_f1_score did not improve from 0.70170
# Epoch 20/100
# 223/223 [==============================] - 47s 209ms/step - loss: 1.0326 - accuracy: 0.8274 - micro_f1_score: 0.8274 - macro_f1_score: 0.7611 - val_loss: 1.1747 - val_accuracy: 0.7056 - val_micro_f1_score: 0.7056 - val_macro_f1_score: 0.6215
#
# Epoch 00020: val_macro_f1_score did not improve from 0.70170
# Epoch 21/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.9099 - accuracy: 0.8342 - micro_f1_score: 0.8342 - macro_f1_score: 0.7783 - val_loss: 1.1870 - val_accuracy: 0.7157 - val_micro_f1_score: 0.7157 - val_macro_f1_score: 0.6140
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00021: val_macro_f1_score did not improve from 0.70170
# Epoch 22/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.7923 - accuracy: 0.8596 - micro_f1_score: 0.8596 - macro_f1_score: 0.7985 - val_loss: 1.0043 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7205
#
# Epoch 00022: val_macro_f1_score improved from 0.70170 to 0.72049, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 23/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.6472 - accuracy: 0.8911 - micro_f1_score: 0.8911 - macro_f1_score: 0.8543 - val_loss: 0.9582 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7237
#
# Epoch 00023: val_macro_f1_score improved from 0.72049 to 0.72367, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 24/100
# 223/223 [==============================] - 49s 220ms/step - loss: 0.5692 - accuracy: 0.9127 - micro_f1_score: 0.9127 - macro_f1_score: 0.8842 - val_loss: 0.9181 - val_accuracy: 0.7716 - val_micro_f1_score: 0.7716 - val_macro_f1_score: 0.7388
# Epoch 00024: val_macro_f1_score improved from 0.72367 to 0.73882, saving model to training_1\w2v_one_layer_lstm_no_emoji.ckpt
# Epoch 25/100
# 223/223 [==============================] - 48s 215ms/step - loss: 0.4963 - accuracy: 0.9314 - micro_f1_score: 0.9314 - macro_f1_score: 0.9111 - val_loss: 0.9106 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7203
#
# Epoch 00025: val_macro_f1_score did not improve from 0.73882
# Epoch 26/100
# 223/223 [==============================] - 47s 213ms/step - loss: 0.4526 - accuracy: 0.9412 - micro_f1_score: 0.9412 - macro_f1_score: 0.9222 - val_loss: 0.9154 - val_accuracy: 0.7817 - val_micro_f1_score: 0.7817 - val_macro_f1_score: 0.7368
#
# Epoch 00026: val_macro_f1_score did not improve from 0.73882
# Epoch 27/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.4445 - accuracy: 0.9420 - micro_f1_score: 0.9420 - macro_f1_score: 0.9271 - val_loss: 0.9258 - val_accuracy: 0.7614 - val_micro_f1_score: 0.7614 - val_macro_f1_score: 0.7142
#
# Epoch 00027: val_macro_f1_score did not improve from 0.73882
# Epoch 28/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.3922 - accuracy: 0.9542 - micro_f1_score: 0.9542 - macro_f1_score: 0.9404 - val_loss: 0.9174 - val_accuracy: 0.7360 - val_micro_f1_score: 0.7360 - val_macro_f1_score: 0.6999
#
# Epoch 00028: val_macro_f1_score did not improve from 0.73882
# Epoch 29/100
# 223/223 [==============================] - 49s 221ms/step - loss: 0.3813 - accuracy: 0.9538 - micro_f1_score: 0.9538 - macro_f1_score: 0.9410 - val_loss: 0.9560 - val_accuracy: 0.7462 - val_micro_f1_score: 0.7462 - val_macro_f1_score: 0.7057
#
# Epoch 00029: val_macro_f1_score did not improve from 0.73882
# Epoch 30/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.3681 - accuracy: 0.9532 - micro_f1_score: 0.9532 - macro_f1_score: 0.9412 - val_loss: 0.9161 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7090
#
# Epoch 00030: val_macro_f1_score did not improve from 0.73882
# Epoch 31/100
# 223/223 [==============================] - 47s 211ms/step - loss: 0.3554 - accuracy: 0.9556 - micro_f1_score: 0.9556 - macro_f1_score: 0.9436 - val_loss: 0.9219 - val_accuracy: 0.7513 - val_micro_f1_score: 0.7513 - val_macro_f1_score: 0.7096
#
# Epoch 00031: val_macro_f1_score did not improve from 0.73882

# %% [markdown]
# ##### Plot learning rate of accuracy and loss

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'loss')
plt.ylim(0,None)
# Out:
# (0.0, 990.7072985991836)

# %% [markdown]
# ##### plot learning rate of micro and macro F1-score

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plot_graphs(history, 'micro_f1_score')
plt.ylim(None,1)
plt.subplot(1,2,2)
plot_graphs(history, 'macro_f1_score')
plt.ylim(0,None)
# Out:
# (0.0, 0.9685606881976128)

# %% [markdown]
# ##### Predict test data on original weights

# %%
#model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 67ms/step - loss: 0.8770 - accuracy: 0.7475 - micro_f1_score: 0.7475 - macro_f1_score: 0.6826
# Test Loss: 0.8769979476928711
# Test Accuracy: 0.747474730014801
# Micro F1-Score: 0.7474746704101562
# Macro F1-Score: 0.6825944781303406

# %% [markdown]
# ##### Load best weights and predict on test data

# %%
model.load_weights(checkpoint_path)
test_loss, test_acc, micro, macro = model.evaluate(testtitle, y_test)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Micro F1-Score:', micro)
print('Macro F1-Score:', macro)
# Out:
# 19/19 [==============================] - 1s 67ms/step - loss: 0.8480 - accuracy: 0.7660 - micro_f1_score: 0.7660 - macro_f1_score: 0.6960
# Test Loss: 0.8480427861213684
# Test Accuracy: 0.7659932374954224
# Micro F1-Score: 0.7659932374954224
# Macro F1-Score: 0.695990800857544

# %% [markdown]
# | Model      | Accuracy |
# | :---       |          ---: |
# | One Layer RNN | 68.35% |
# | One layer LSTM | 75.93% |
# | Two Layer biLSTM | 73.74% |
# | Two Layer biLSTM + Dropout | 73.91% |
# | Proposed Method: Two Layer biLSTM + Dropout + Batch Normalization | 76.60%|
